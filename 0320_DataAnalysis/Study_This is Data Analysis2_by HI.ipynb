# %%
from IPython.display import Image

Image("14.jpg")

# %% [markdown]
# -----

# %% [markdown]
# # 2.1) 나무위키 최신 변경 문서의 키워드 분석

# %% [markdown]
# ### 바로가기

# %% [markdown]
# - [<Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기](#<Step1.-크롤링>-:-크롤링으로-웹-데이터-가져오기)
#     - [BeautifulSoup을 이용한 웹 크롤링]
#     - [나무위키 최근변경 데이터 크롤링]
# - [<Step2. 추출> : 키워드 추출](#<Step2.-추출>-:-키워드-추출)
#     - [텍스트 데이터 전처리]
#     - [말뭉치 만들기]
#     - [konlpy를 이용한 키워드 추출]
#     - [키워드 가다듬기]
# - [<Step3. 시각화> : 워드 클라우드 시각화](#<Step3.-시각화>-:-워드-클라우드-시각화)
#     - [pytagcloud 사용하기]
#     - [나무위키 키워드 시각화]

# %% [markdown]
# -----

# %%
# -*- coding: utf-8 -*-

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <Step1. 크롤링> : 크롤링으로 웹 데이터 가져오기

# %% [markdown]
# ### [BeautifulSoup을 이용한 웹 크롤링]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     - (env_name) `pip install requests`
#     - (env_name) `pip install beautifulsoup4`
#     - (env_name) `pip install lxml`
# - 혹은 아래의 코드로 라이브러리를 설치합니다.

# %%
# !pip install requests beautifulsoup4 lxml
# Out:
# Requirement already satisfied: requests in c:\users\heian\anaconda3\lib\site-packages (2.22.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\heian\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: lxml in c:\users\heian\anaconda3\lib\site-packages (4.4.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\heian\anaconda3\lib\site-packages (from requests) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\heian\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\heian\anaconda3\lib\site-packages (from requests) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\heian\anaconda3\lib\site-packages (from requests) (2019.9.11)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\heian\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.3)

# %% [markdown]
# -----

# %% [markdown]
# ##### 페이지 리스트 가져오기

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content

soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
print(req) #응답 코드가 나옴! 
print(type(req))
#req.
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %% [markdown]
# ### ◎ reqest 모듈의 메소드들
# - req.content : 응답한 데이터(byte), 음악, 비디오 등 byte자체를 받아 저장할 때
# - req.text : 응답한 데이터(str), 주로 웹페이지 소스코드나 문자데이터 확인할 때
#
#
# - req.encoding : 응답 데이터 인코딩 방식
# - req.url : 요청한 url
# - req.status_code: 응답 결과 (200: 성공(ok), 400대: 실패))
# - req.headers: 응답데이터의 헤더

# %%
req.encoding #응답한 데이터의 인코딩 방식
# Out:
# 'utf-8'

# %% [markdown]
# #### ▶ req.encoding : 응답한 데이터의 인코딩 방식
#   - 1) 일반적으로 한글이 깨지지 않음 : 유니코드 인코딩(예: UTF-8 등), 한글 인코딩(예: EUC-KR)
#   - 2) 영문인코딩인 경우 한글이 깨짐 -> ISO-8859-1
#
#  - 해결방법:Response 객체의 encoding 을 한글인코딩(예: EUC-KR)이나 None (인코딩 추즉을 하지 않도록) 으로 지정한 후, text 속성 읽기

# %%
req.url
# Out:
# 'https://namu.wiki/RecentChanges'

# %%
req.headers
# Out:
# {'Date': 'Thu, 12 Mar 2020 15:35:13 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d87ffc548e618e8b9c1b4bce8c123729c1584027313; expires=Sat, 11-Apr-20 15:35:13 GMT; path=/; domain=.namu.wiki; HttpOnly; SameSite=Lax; Secure, __cfuid=Bqls04m0J4EtWho5KS%2F%2BwQ%3D%3D; Domain=.namu.wiki; Path=/; Expires=Fri, 12 Mar 2021 15:35:13 GMT; HttpOnly', 'ETag': 'W/"2dec3-8ofBrMnHe/Qul644+rD/6AZ0JHo"', 'X-Namu-Region': 'J', 'X-Powered-By': 'PHP/5.4.20', 'Content-Encoding': 'gzip', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Alt-Svc': 'h3-27=":443"; ma=86400, h3-25=":443"; ma=86400, h3-24=":443"; ma=86400, h3-23=":443"; ma=86400', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '572e95731c57e9cc-ICN'}

# %%
req.status_code
# Out:
# 200

# %%
from IPython.display import Image

Image("3.jpg")

# %%
html
# Out:
# b'<!doctype html>\n<html data-n-head-ssr><head ><title>\xec\xb5\x9c\xea\xb7\xbc \xeb\xb3\x80\xea\xb2\xbd\xeb\x82\xb4\xec\x97\xad - \xeb\x82\x98\xeb\xac\xb4\xec\x9c\x84\xed\x82\xa4</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, width=device-width"><meta data-n-head="ssr" http-equv="x-ua-compatible" content="ie=edge"><meta data-n-head="ssr" name="generator" content="the seed"><meta data-n-head="ssr" name="mobile-web-app-capable" content="yes"><meta data-n-head="ssr" name="application-name" content="\xeb\x82\x98\xeb\xac\xb4\xec\x9c\x84\xed\x82\xa4"><meta data-n-head="ssr" name="msapplication-tooltip" content="\xeb\x82\x98\xeb\xac\xb4\xec\x9c\x84\xed\x82\xa4"><meta data-n-head="ssr" name="msapplication-starturl" content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8"><meta data-n-head="ssr" name="theme-color" content="#008275"><meta data-n-head="ssr" name="googlebot" content="noarchive"><link data-n-head="ssr" rel="canonical" href="https://namu.wiki/RecentChanges"><link data-n-head="ssr" rel="search" type="application/opensearchdescription+xml" title="\xeb\x82\x98\xeb\xac\xb4\xec\x9c\x84\xed\x82\xa4" href="/opensearch.xml"><link data-n-head="ssr" rel="shortcut icon" href="/favicon.ico"><link data-n-head="ssr" rel="icon" href="/img/icon.png" sizes="128x128"><link data-n-head="ssr" rel="apple-touch-icon" href="/img/apple_icon.png"><script data-n-head="ssr" async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><link rel="preload" href="/skins/senkawa/30f440e639a3df5fc94f.js" as="script"><link rel="preload" href="/skins/senkawa/2b6b48c3632ad58fca52.css" as="style"><link rel="preload" href="/skins/senkawa/2b6b48c3632ad58fca52.js" as="script"><link rel="preload" href="/skins/senkawa/766e24677166431d4ab3.css" as="style"><link rel="preload" href="/skins/senkawa/766e24677166431d4ab3.js" as="script"><link rel="stylesheet" href="/skins/senkawa/2b6b48c3632ad58fca52.css"><link rel="stylesheet" href="/skins/senkawa/766e24677166431d4ab3.css"></head><body ><div id="app" data-server-rendered="true"><!----><div class="app senkawa-fixed-size senkawa-fixed-1300" data-v-459c4f00><div data-v-4c6f7db9 data-v-459c4f00><nav data-v-3674418a data-v-459c4f00><a href="/" data-v-67486d66 data-v-459c4f00></a> <ul data-v-97145b5e data-v-459c4f00><li data-v-69a85a70 data-v-459c4f00><a href="/RecentChanges" title="\xec\xb5\x9c\xea\xb7\xbc \xeb\xb3\x80\xea\xb2\xbd" data-v-69a85a70><span class="i ion-md-compass" data-v-69a85a70></span> <span class="t" data-v-69a85a70>\xec\xb5\x9c\xea\xb7\xbc \xeb\xb3\x80\xea\xb2\xbd</span></a></li> <li data-v-69a85a70 data-v-459c4f00><a href="/RecentDiscuss" title="\xec\xb5\x9c\xea\xb7\xbc \xed\x86\xa0\xeb\xa1\xa0" data-v-69a85a70><span class="i ion-md-text" data-v-69a85a70></span> <span class="t" data-v-69a85a70>\xec\xb5\x9c\xea\xb7\xbc \xed\x86\xa0\xeb\xa1\xa0</span></a></li> <li data-v-6d889646 data-v-459c4f00><a href="#" title="\xed\x8a\xb9\xec\x88\x98 \xea\xb8\xb0\xeb\x8a\xa5" data-v-6d889646><span class="i ion-ios-cube" data-v-6d889646></span> <span class="t" data-v-6d889646>\xed\x8a\xb9\xec\x88\x98 \xea\xb8\xb0\xeb\x8a\xa5</span></a> <div data-v-6d889646><a href="//board.namu.wiki/" title="\xea\xb2\x8c\xec\x8b\x9c\xed\x8c\x90" data-v-193fc2b2 data-v-459c4f00><span class="i ion-ios-clipboard" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>\xea\xb2\x8c\xec\x8b\x9c\xed\x8c\x90</span></a> <div data-v-12e4a4c3 data-v-459c4f00></div> <a href="/NeededPages" title="\xec\x9e\x91\xec\x84\xb1\xec\x9d\xb4 \xed\x95\x84\xec\x9a\x94\xed\x95\x9c \xeb\xac\xb8\xec\x84\x9c" data-v-193fc2b2 data-v-459c4f00><span class="i ion-md-alert" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>\xec\x9e\x91\xec\x84\xb1\xec\x9d\xb4 \xed\x95\x84\xec\x9a\x94\xed\x95\x9c \xeb\xac\xb8\xec\x84\x9c</span></a> <a href="/OrphanedPages" title="\xea\xb3\xa0\xeb\xa6\xbd\xeb\x90\x9c \xeb\xac\xb8\xec\ ...

# %%
html2 = req.text
html2
# Out:
# '<!doctype html>\n<html data-n-head-ssr><head ><title>최근 변경내역 - 나무위키</title><meta data-n-head="ssr" charset="utf-8"><meta data-n-head="ssr" name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0, width=device-width"><meta data-n-head="ssr" http-equv="x-ua-compatible" content="ie=edge"><meta data-n-head="ssr" name="generator" content="the seed"><meta data-n-head="ssr" name="mobile-web-app-capable" content="yes"><meta data-n-head="ssr" name="application-name" content="나무위키"><meta data-n-head="ssr" name="msapplication-tooltip" content="나무위키"><meta data-n-head="ssr" name="msapplication-starturl" content="/w/%EB%82%98%EB%AC%B4%EC%9C%84%ED%82%A4:%EB%8C%80%EB%AC%B8"><meta data-n-head="ssr" name="theme-color" content="#008275"><meta data-n-head="ssr" name="googlebot" content="noarchive"><link data-n-head="ssr" rel="canonical" href="https://namu.wiki/RecentChanges"><link data-n-head="ssr" rel="search" type="application/opensearchdescription+xml" title="나무위키" href="/opensearch.xml"><link data-n-head="ssr" rel="shortcut icon" href="/favicon.ico"><link data-n-head="ssr" rel="icon" href="/img/icon.png" sizes="128x128"><link data-n-head="ssr" rel="apple-touch-icon" href="/img/apple_icon.png"><script data-n-head="ssr" async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><link rel="preload" href="/skins/senkawa/30f440e639a3df5fc94f.js" as="script"><link rel="preload" href="/skins/senkawa/2b6b48c3632ad58fca52.css" as="style"><link rel="preload" href="/skins/senkawa/2b6b48c3632ad58fca52.js" as="script"><link rel="preload" href="/skins/senkawa/766e24677166431d4ab3.css" as="style"><link rel="preload" href="/skins/senkawa/766e24677166431d4ab3.js" as="script"><link rel="stylesheet" href="/skins/senkawa/2b6b48c3632ad58fca52.css"><link rel="stylesheet" href="/skins/senkawa/766e24677166431d4ab3.css"></head><body ><div id="app" data-server-rendered="true"><!----><div class="app senkawa-fixed-size senkawa-fixed-1300" data-v-459c4f00><div data-v-4c6f7db9 data-v-459c4f00><nav data-v-3674418a data-v-459c4f00><a href="/" data-v-67486d66 data-v-459c4f00></a> <ul data-v-97145b5e data-v-459c4f00><li data-v-69a85a70 data-v-459c4f00><a href="/RecentChanges" title="최근 변경" data-v-69a85a70><span class="i ion-md-compass" data-v-69a85a70></span> <span class="t" data-v-69a85a70>최근 변경</span></a></li> <li data-v-69a85a70 data-v-459c4f00><a href="/RecentDiscuss" title="최근 토론" data-v-69a85a70><span class="i ion-md-text" data-v-69a85a70></span> <span class="t" data-v-69a85a70>최근 토론</span></a></li> <li data-v-6d889646 data-v-459c4f00><a href="#" title="특수 기능" data-v-6d889646><span class="i ion-ios-cube" data-v-6d889646></span> <span class="t" data-v-6d889646>특수 기능</span></a> <div data-v-6d889646><a href="//board.namu.wiki/" title="게시판" data-v-193fc2b2 data-v-459c4f00><span class="i ion-ios-clipboard" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>게시판</span></a> <div data-v-12e4a4c3 data-v-459c4f00></div> <a href="/NeededPages" title="작성이 필요한 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-md-alert" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>작성이 필요한 문서</span></a> <a href="/OrphanedPages" title="고립된 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-ios-link" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>고립된 문서</span></a> <a href="/UncategorizedPages" title="분류가 되지 않은 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-md-help" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>분류가 되지 않은 문서</span></a> <a href="/OldPages" title="편집된 지 오래된 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-ios-pause" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>편집된 지 오래된 문서</span></a> <a href="/ShortestPages" title="내용이 짧은 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-md-create" data-v-193fc2b2></span> <span class="t" data-v-193fc2b2>내용이 짧은 문서</span></a> <a href="/LongestPages" title="내용이 긴 문서" data-v-193fc2b2 data-v-459c4f00><span class="i ion-md-heart" da ...

# %% [markdown]
# ### BeautifulSoup
#
# Requests는 정말 좋은 라이브러리이지만, html을 '의미있는', 즉 Python이 이해하는 객체 구조로 만들어주지는 못한다.
#
# 위에서 req.text는 python의 문자열(str)객체를 반환할 뿐이기 때문에 정보를 추출하기가 어렵다.
#
# 따라서 BeautifulSoup을 이용하게 된다. 이 BeautifulSoup은 html 코드를 Python이 이해하는 객체 구조로 변환하는 Parsing을 맡고 있고, 이 라이브러리를 이용해 우리는 제대로 된 '의미있는' 정보를 추출해 낼 수 있다.

# %%
from IPython.display import Image


Image("2.jpg")

# %%
#Soup객체에 대해서 알아보자!
type(soup)

#soup객체의 메소드들
#soup.
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# #### Beautifulsoup의 find 관련 메소드  : find(), find_all()
# 1) 태그 종류로 찾기
#   - find(태그종류)  #td, tr, table...
#   - 태그 종류 정리 : https://sime.tistory.com/90
#
# 2) 클래스 값으로 찾기
#    -find("[태그명]", class_="[클래스명]")
#
# 3) id 명으로 찾기
#    -find("[태그명]", id_="[아이디명]")
#
# 4) 옵션들 넣어서 찾기
#   - find()
#     - find(name, attrs, recursive, string, **kwargs)
#     - 해당 조건에 맞는 하나의 태그를 가져온다. 중복이면 가장 첫 번째 태그를 가져온다.
#
#
#    -  find_all()
#      - find_all(name, attrs, recursive, string, limit, **kwargs)
#      - 해당 조건에 맞는 모든 태그들을 가져온다

# %%
# find(), find_all() 테스트해보기! 
url_gongyou= "https://ko.wikipedia.org/wiki/%ED%8E%AD%EC%88%98"
req2 = requests.get(url_pengsoo)

html2 = req2.text
soup2 = BeautifulSoup(html, 'lxml')
print("*****find()일때!*** \n",soup2.find("td"))
print("*****findall()일때!*** \n",soup2.find_all("td"))
# Out:
# *****find()일때!***
#  <td colspan="2" style="text-align:center"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:%ED%8E%AD%EC%88%98.jpg"><img alt="" data-file-height="310" data-file-width="500" decoding="async" height="186" src="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/300px-%ED%8E%AD%EC%88%98.jpg" srcset="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/450px-%ED%8E%AD%EC%88%98.jpg 1.5x, //upload.wikimedia.org/wikipedia/ko/d/d4/%ED%8E%AD%EC%88%98.jpg 2x" width="300"/></a></td>
# *****findall()일때!***
#  [<td colspan="2" style="text-align:center"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:%ED%8E%AD%EC%88%98.jpg"><img alt="" data-file-height="310" data-file-width="500" decoding="async" height="186" src="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/300px-%ED%8E%AD%EC%88%98.jpg" srcset="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/450px-%ED%8E%AD%EC%88%98.jpg 1.5x, //upload.wikimedia.org/wikipedia/ko/d/d4/%ED%8E%AD%EC%88%98.jpg 2x" width="300"/></a></td>, <td>2019년 3월 20일</td>, <td>펭귄</td>, <td>10살</td>, <td>210cm</td>, <td>90~103kg</td>, <td><span class="flagicon"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:Proposed_flag_of_Antarctica_(Graham_Bartram).svg" title="남극"><img alt="남극" class="thumbborder" data-file-height="496" data-file-width="744" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg
>, <td><a class="external autonumber" href="https://www.youtube.com/watch?v=n5_ciLUoykY" rel="nofollow">[8]</a>
# </td>, <td><a class="mw-redirect" href="/wiki/%EC%A0%95%EA%B4%80%EC%9E%A5" title="정관장">정관장</a></td>, <td>2020년</td>, <td><a class="external autonumber" href="https://www.youtube.com/watch?v=YYpashf_Qc4" rel="nofollow">[9]</a></td>, <td>
# </td>, <td><a class="mw-redirect" href="/wiki/%EB%8F%99%EC%9B%90%EC%B0%B8%EC%B9%98" title="동원참치">동원참치</a></td>, <td>2020년</td>, <td></td>, <td><a class="external autonumber" href="https://news.joins.com/article/23666073" rel="nofollow">[10]</a>
# </td>, <td><a class="new" href="/w/index.php?title=%EC%83%A4%ED%94%84%EB%9E%80_%EC%95%84%EC%9A%B0%EB%9D%BC&amp;action=edit&amp;redlink=1" title="샤프란 아우라 (없는 문서)">샤프란 아우라</a></td>, <td>2020년</td>, <td></td>, <td><a class="external autonumber" href="http://www.lghnh.com/news/press/view.jsp?seq=3190" rel="nofollow">[11]</a>
# </td>, <td><a class="mw-redirect" href="/wiki/%EB%B6%95%EC%96%B4%EC%8B%B8%EB%A7%8C%EC%BD%94" title="붕어싸만코">붕어싸만코</a>, <a class="new" href="/w/index.php?title=%EB%B9%B5%EB%98%90%EC%95%84&amp;action=edit&amp;redlink=1" title="빵또아 (없는 문서)">빵또아</a></td>, <td>2020년</td>, <td><a class="external autonumber" href="https://www.youtube.com/watch?v=3LzXDPj8nLI" rel="nofollow">[12]</a></td>, <td><a class="external autonumber" href="https://n.news.naver.com/article/382/0000793946" rel="nofollow">[13]</a>
# </td>, <td><a href="/wiki/%EB%AF%B8%EB%8B%9B%EB%A9%94%EC%9D%B4%EB%93%9C" title="미닛메이드">미닛메이드</a></td>, <td>2020년</td>, <td></td>, <td><a class="external autonumber" href="https://news.mt.co.kr/mtview.php?no=2020012909182796114" rel="nofollow">[14]</a>
# </td>, <td><a class="mw-redirect" href="/wiki/%EB%B9%84%ED%83%80500" title="비타500">비타500</a></td>, <td>2020년</td>, <td></td>, <td><a class="external autonumber" href="http://www.donga.com/news/article/all/20200302/99959697/1" rel="nofollow">[15]</a>
# </td>]

# %%
#2) 클래스 값으로 찾기 

a= soup2.find("table", class_ = "infobox")
b=a.find_all("a")


print(a)
print(type(b))
# b=a.find_all(name ="a")
# print(b)
# Out:
# <table class="infobox" style="width:25em"><tbody><tr><th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;background:#DEDEE2;">펭수</th></tr><tr><td colspan="2" style="text-align:center"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:%ED%8E%AD%EC%88%98.jpg"><img alt="" data-file-height="310" data-file-width="500" decoding="async" height="186" src="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/300px-%ED%8E%AD%EC%88%98.jpg" srcset="//upload.wikimedia.org/wikipedia/ko/thumb/d/d4/%ED%8E%AD%EC%88%98.jpg/450px-%ED%8E%AD%EC%88%98.jpg 1.5x, //upload.wikimedia.org/wikipedia/ko/d/d4/%ED%8E%AD%EC%88%98.jpg 2x" width="300"/></a></td></tr><tr><th scope="row" style="width:25%;"><b>첫 등장</b></th><td>2019년 3월 20일</td></tr><tr><th colspan="2" style="text-align:center;background:#DEDEE2;">정보</th></tr><tr><th scope="row" style="width:25%;"><b>종족</b></th><td>펭귄</td></tr><tr><th scope="row" style="width:25%;"><b>나이</b></th><td>10살</td></tr><tr><th scope="row" style="width:25%;"><b>신장</b></th><td>210cm</td></tr><tr><th scope="row" style="width:25%;"><b>체중</b></th><td>90~103kg</td></tr><tr><th scope="row" style="width:25%;"><b>태어난 곳</b></th><td><span class="flagicon"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:Proposed_flag_of_Antarctica_(Graham_Bartram).svg" title="남극"><img alt="남극" class="thumbborder" data-file-height="496" data-file-width="744" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg/22px-Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg/33px-Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bb/Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg/44px-Proposed_flag_of_Antarctica_%28Graham_Bartram%29.svg.png 2x" width="22"/></a></span> <a href="/wiki/%EB%82%A8%EA%B7%B9" title="남극">남극</a></td></tr><tr><th scope="row" style="width:25%;"><b>사는 곳</b></th><td><a href="/wiki/%ED%95%9C%EA%B5%AD%EA%B5%90%EC%9C%A1%EB%B0%A9%EC%86%A1%EA%B3%B5%EC%82%AC" title="한국교육방송공사">EBS</a> 소품실, <a href="/wiki/%ED%95%9C%EA%B5%AD%EA%B5%90%EC%9C%A1%EB%B0%A9%EC%86%A1%EA%B3%B5%EC%82%AC" title="한국교육방송공사">EBS</a> 로비 2층 펭숙소</td></tr><tr><th scope="row" style="width:25%;"><b>능력/특기</b></th><td><a class="mw-redirect" href="/wiki/%EC%9A%94%EB%93%A4%EC%86%A1" title="요들송">요들송</a>, 엣헴송, 어디로송, 미국춤, 유기농춤, 펭귄어, <a class="mw-disambig" href="/wiki/%EB%9E%A9" title="랩">랩</a>, <a href="/wiki/%EB%B9%84%ED%8A%B8%EB%B0%95%EC%8A%A4" title="비트박스">비트박스</a>, <a href="/wiki/%ED%8C%90%EC%86%8C%EB%A6%AC" title="판소리">판소리</a>, 찹쌀떡 노동요, 드럼 연주</td></tr><tr><th scope="row" style="width:25%;"><b>소속 단체</b></th><td><a class="mw-redirect" href="/wiki/EBS" title="EBS">EBS</a></td></tr><tr><th scope="row" style="width:25%;"><b>직업</b></th><td><a class="mw-redirect" href="/wiki/EBS" title="EBS">EBS</a> 연습생, <a href="/wiki/%EC%9C%A0%ED%8A%9C%EB%B8%8C" title="유튜브">유튜브</a> 크리에이터</td></tr></tbody></table>
# <class 'bs4.element.ResultSet'>

# %%
from IPython.display import Image

Image("1.jpg")

# %%
import requests
from bs4 import BeautifulSoup
import re

# 크롤링할 사이트 주소를 정의합니다.
source_url = "https://namu.wiki/RecentChanges"

# 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
req = requests.get(source_url)
html = req.content

soup = BeautifulSoup(html, 'lxml')
contents_table = soup.find(name="table")
table_body = contents_table.find(name="tbody")
table_rows = table_body.find_all(name="tr")

# %%
print("contents_table: ",type(contents_table))
print("table_body: ",type(table_body))
print("table_rows: ",type(table_rows))
# Out:
# contents_table:  <class 'bs4.element.Tag'>
# table_body:  <class 'bs4.element.Tag'>
# table_rows:  <class 'bs4.element.ResultSet'>

# %%
print(len(table_rows))
# Out:
# 109

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(0, len(table_rows)):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# https://namu.wiki/w/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)
# https://namu.wiki/w/%EB%8C%80%ED%95%99%20%EA%B0%84%20%ED%86%B5%ED%8F%90%ED%95%A9
# https://namu.wiki/w/%EC%8A%AC%EB%A6%AC%ED%94%BC%20%ED%86%A0%EB%93%9C
# https://namu.wiki/w/%EC%8A%A4%ED%8B%B1%20%EC%97%A0%ED%8C%8C%EC%9D%B4%EC%96%B4%EC%A6%88
# https://namu.wiki/w/%EB%A6%AC%EA%B3%A0%EB%AA%A8%EB%A5%B4

# %%
# a태그의 href 속성을 리스트로 추출하여, 크롤링 할 페이지 리스트를 생성합니다.
page_url_base = "https://namu.wiki"
page_urls = []
for index in range(2):
    first_td = table_rows[index].find_all('td')[0]
    td_url = first_td.find_all('a')
    print("*****first_td:",first_td)
    print("-----------------------",index,"번째---------------------------------------------------------------------")
    print("*****td_url:",td_url)   
    print("--------------------------------------------------------------------------------------------------------")
    if len(td_url) > 0:
        page_url = page_url_base + td_url[0].get('href')
        if 'png' not in page_url:
            page_urls.append(page_url)

# 중복 url을 제거합니다.
page_urls = list(set(page_urls))
for page in page_urls[:5]:
    print(page)
# Out:
# *****first_td: <td data-v-24f321a4=""><a data-v-24f321a4="" href="/w/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">환마황제 라비엘</a> <a data-v-24f321a4="" href="/history/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">[역사]</a> <a data-v-24f321a4="" href="/diff/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98?rev=88&amp;oldrev=87">[비교]</a> <a data-v-24f321a4="" href="/discuss/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">[토론]</a> <span data-v-24f321a4="">(<span class="p" data-v-24f321a4="" data-v-3ee54395="">+35</span>)</span></td>
# ----------------------- 0 번째---------------------------------------------------------------------
# *****td_url: [<a data-v-24f321a4="" href="/w/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">환마황제 라비엘</a>, <a data-v-24f321a4="" href="/history/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">[역사]</a>, <a data-v-24f321a4="" href="/diff/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98?rev=88&amp;oldrev=87">[비교]</a>, <a data-v-24f321a4="" href="/discuss/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98">[토론]</a>]
# --------------------------------------------------------------------------------------------------------
# *****first_td: <td data-v-24f321a4=""><a data-v-24f321a4="" href="/w/%EC%A0%95%EC%A7%80%EC%86%8C">정지소</a> <a data-v-24f321a4="" href="/history/%EC%A0%95%EC%A7%80%EC%86%8C">[역사]</a> <a data-v-24f321a4="" href="/diff/%EC%A0%95%EC%A7%80%EC%86%8C?rev=145&amp;oldrev=144">[비교]</a> <a data-v-24f321a4="" href="/discuss/%EC%A0%95%EC%A7%80%EC%86%8C">[토론]</a> <span data-v-24f321a4="">(<span class="p" data-v-24f321a4="" data-v-3ee54395="">+29</span>)</span></td>
# ----------------------- 1 번째---------------------------------------------------------------------
# *****td_url: [<a data-v-24f321a4="" href="/w/%EC%A0%95%EC%A7%80%EC%86%8C">정지소</a>, <a data-v-24f321a4="" href="/history/%EC%A0%95%EC%A7%80%EC%86%8C">[역사]</a>, <a data-v-24f321a4="" href="/diff/%EC%A0%95%EC%A7%80%EC%86%8C?rev=145&amp;oldrev=144">[비교]</a>, <a data-v-24f321a4="" href="/discuss/%EC%A0%95%EC%A7%80%EC%86%8C">[토론]</a>]
# --------------------------------------------------------------------------------------------------------
# https://namu.wiki/w/%EC%A0%95%EC%A7%80%EC%86%8C
# https://namu.wiki/w/%ED%99%98%EB%A7%88%ED%99%A9%EC%A0%9C%20%EB%9D%BC%EB%B9%84%EC%97%98

# %% [markdown]
# -----

# %% [markdown]
# ##### 페이지내 텍스트 구조 확인

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')

contents_table = soup.find(name="article")
title = contents_table.find_all('h1')[0]
category = contents_table.find_all('ul')[0]
content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})


content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# 한유진(우아한 모녀)
#
#
# 우아한 모녀/등장인물드라마 히로인
#
#
# 한유진 / 제니스  한 / 홍유라배우: 차예련1. 개요2. 작중 행적3. 평가 제니스. 복수의 화신이 되어 사랑하는 남자까지도 복수의 도구로 이용했지만 결국 사랑 앞에, 또 다른 진실 앞에 무너져야 하는 그녀.차미연(캐리정)에 의해 유괴된 딸.폭풍같고 불같은 열정을 가슴에 품고 있는 여자.귀티나는 단아한 외모에 영민하고 깔끔한 성격.자존심이 강해 쉽게 곁을 주지않지만 한 번 마음을 준 상대에게는 한없이약한 성녀와 마녀 두 가지 모습을 가지고 있다.엄마의 기대에 부응하며 실력과 미모를 갖춘 재원으로 성장한 그녀. 거기에 엄마의 재력까지 더해져 그야말로 완벽 그 자체였다.누구나 인정하는 미모의 엘리트.하지만 그녀는 자신을 “복수를 위한 엄마의 걸작품”이라고 생각한다.엄마 앞에서 내색한적은 없다. 엄마의 딸로 태어난 이상, 그녀는 그 운명을 일찌감치 받아들이기로 했다. 그녀는 엄마를 사랑하는 착한 딸이니까.우아한 모녀의 등장인물로 차예련이 연기한다.1990년생 (30세). 불 같은 열정을 가슴에 품고 있는 엘리트 중의 엘리트. 서은하와 홍인철의 친딸로, 캐리 정이 차미연이었던 젊은 시절에 제이그룹에 대한 복수를 위해서 어린아이였던 유진을 유괴하는 바람에 생이별을 당한 것. 당시 서은하는 둘째인 홍세라를 낳기 위하여 진통을 겪고 있었는데, 하필이면 백화점에서 진통을 겪은 탓에 홍유라를 제대로 챙기지 못했다. 그 자리에서 구급대원들에게 실려갈 때에도 은하는 유라를 찾았지만, 결국 그 때 차미연이 유모차를 끌고 간 뒤 캐나다로 자취를 감췄다. 즉, 홍세라와는 친자매로 진짜 이름은 홍유라이다.[1]물론 본인은 이 사실을 모르고 캐리정의 친딸이라 믿고 캐리정의 복수를 위해 자라나게 된다. 비록 엄마의 복수를 위한 도구처럼 되어버리고 삶이 행복하지 않은 것 같음에도 엄마를 위해선 감수해야한다는 목적으로 살아왔다. 참고로 어렸을때 캐나다에서 피팅룸에 갇힌 
와 자신이 모녀라는 유전자 검사지였다. 믿지 못하지만 홍세라가 홍인철, 서은하가 자신을 찾아갔던 것을 다시 상기시켜주자 그제서야 자신이 느꼈던 수많은 의문들이 풀리면서 자신과 캐리, 구해준의 정체를 깨닫고 패닉에 빠져버린다. 집으로 다시 돌아올때는 여전히 충격에 새벽까지 잠을 이루지 못하다가 누군가에게 전화를 하고[11] 결혼식에 간다. 그러나 결혼식 준비 ...

# %%
req = requests.get(page_urls[0])
html = req.content
soup = BeautifulSoup(html, 'lxml')

contents_table = soup.find(name="article")

print("**************contents_table:",contents_table)
print("-------------------------------contents_table 끝---------------------------------------------------------")

title = contents_table.find_all('h1')[0]
print("**************title:",title)
print("-------------------------------------title 끝---------------------------------------------------")

category = contents_table.find_all('ul')[0]
print("**************category:",category)
print("---------------------------------------category 끝-------------------------------------------------")

content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
print("**************content_paragraphs:",content_paragraphs)
print("-------------------------------------------content_paragraphs 끝---------------------------------------------")

content_corpus_list = []

for paragraphs in content_paragraphs:
    content_corpus_list.append(paragraphs.text)
content_corpus = "".join(content_corpus_list)

print(title.text)
print("\n")
print(category.text)
print("\n")
print(content_corpus)
# Out:
# **************contents_table: <article data-v-24bb48eb="" data-v-459c4f00=""><!-- --> <!-- --> <div class="r" data-v-24bb48eb="" data-v-5058474b=""><div class="g" data-v-5058474b=""><a data-v-24bb48eb="" href="/member/star/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)"><span class="icon ion-ios-star-outline" data-v-24bb48eb=""></span> 0</a> <!-- --> <a data-v-24bb48eb="" href="/backlink/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)">역링크</a> <a data-v-24bb48eb="" href="/discuss/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)">토론</a> <a data-v-24bb48eb="" href="/edit/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)" rel="nofollow">편집</a> <a data-v-24bb48eb="" href="/history/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)">역사</a> <!-- --> <a data-v-24bb48eb="" href="/acl/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)" rel="nofollow">ACL</a> <!-- --></div></div> <h1 data-v-24bb48eb=""><a data-v-24bb48eb="" href="/w/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)"><!-- -->한유진(우아한 모녀)</a> <!-- --></h1> <p data-v-24bb48eb="">최근 수정 시각: <time data-v-24bb48eb="" datetime="2020-03-12T17:52:21.000Z">2020-03-12 17:52:21</time></p> <!-- --> <div class="ad" data-v-24bb48eb=""><div data-v-24bb48eb="" id="chika3d075367"></div></div> <!-- --> <div data-v-459c4f00="" data-v-76ca162d=""><!-- --> <!-- --> <div data-v-76ca162d="" data-v-7be20f4f=""><h2 data-v-7be20f4f="">분류</h2> <ul data-v-7be20f4f=""><li data-v-7be20f4f=""><a data-v-7be20f4f="" href="/w/%EB%B6%84%EB%A5%98:%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80/%EB%93%B1%EC%9E%A5%EC%9D%B8%EB%AC%BC">우아한 모녀/등장인물</a></li><li data-v-7be20f4f=""><a data-v-7be20f4f="" href="/w/%EB%B6%84%EB%A5%98:%EB%93%9C%EB%9D%BC%EB%A7%88%20%ED%9E%88%EB%A1%9C%EC%9D%B8">드라마 히로인</a></li></ul></div> <!-- --> <div data-v-76ca162d=""><!-- --> <!-- --> <div data-v-25777ca3="" data-v-76ca162d=""><div class="w" data-v-25777ca3=""><div class="wiki-table-wrap table-center" style="width:600px"><table class="wiki-table" style="width:100%; border:2px solid #451D26;"><tbody><tr><td style="background-color:#451D26; text-align:center;"><div class="wiki-paragraph"><span class="wiki-color" style="color:#FFFFFF"><strong><span class="wiki-size size-up-1">한유진 / 제니스  한 / 홍유라</span></strong></span></div></td></tr><tr><td style="background-color:#ffffff; text-align:center;"><div class="wiki-paragraph"><div style="margin:-5px -10px;"><a class="wiki-link-internal" href="/w/%ED%8C%8C%EC%9D%BC:%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80%20%ED%95%9C%EC%9C%A0%EC%A7%84.jpg" rel="nofollow" title="파일:우아한 모녀 한유진.jpg"><span class="wiki-image-align-normal" style="width:100%;"><span class="wiki-image-wrapper" style="width: 100%;"><img alt="파일:우아한 모녀 한유진.jpg" class="wiki-image" src="//w.namu.la/s/f07765597ac12bf07fbf2ff6c80234099b45752e3cac6cbf11931d6690d618668fdbddd032a6dd06866b0ac42b5af012ae651aeb79388632160e166c56254219a1e0bbc54b8bb1653bf2a269b5c0b6c71f78a29fe2656255bee754802565ea4f" width="100%"/></span></span></a></div></div></td></tr><tr><td style="background-color:#FFFFFF; text-align:center;"><div class="wiki-paragraph">배우: <a class="wiki-link-internal" href="/w/%EC%B0%A8%EC%98%88%EB%A0%A8" title="차예련"><span class="wiki-color" style="color:#000000">차예련</span></a></div></td></tr></tbody></table></div><div class="wiki-paragraph"><div class="wiki-macro-toc" id="toc"><div class="toc-indent"><span class="toc-item"><a href="#s-1">1</a>. 개요</span><span class="toc-item"><a href="#s-2">2</a>. 작중 행적</span><span class="toc-item"><a href="#s-3">3</a>. 평가</span></div></div> </div><h2 class="wiki-heading"><a href="#toc" id="s-1">1.</a> <span id="개요">개요<span class="wiki-edit-section"><a href="/edit/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)?section=1" rel="nofollow">[편집]</a></span></span></h2><div class="w ...
# 이 저작물은 <a href="//creativecommons.org/licenses/by-nc-sa/2.0/kr/" rel="license">CC BY-NC-SA 2.0 KR</a>에 따라 이용할 수 있습니다. (단, 라이선스가 명시된 일부 문서 및 삽화 제외)<br/>
# 기여하신 문서의 저작권은 각 기여자에게 있으며, 각 기여자는 기여하신 부분의 저작권을 갖습니다.
# <br/>
# <br/>
# 나무위키는 백과사전이 아니며 검증되지 않았거나, 편향적이거나, 잘못된 서술이 있을 수 있습니다.<br/>
# 나무위키는 위키위키입니다. 여러분이 직접 문서를 고칠 수 있으며, 다른 사람의 의견을 원할 경우 직접 토론을 발제할 수 있습니다.</p></footer></article>
# -------------------------------contents_table 끝---------------------------------------------------------
# **************title: <h1 data-v-24bb48eb=""><a data-v-24bb48eb="" href="/w/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)"><!-- -->한유진(우아한 모녀)</a> <!-- --></h1>
# -------------------------------------title 끝---------------------------------------------------
# **************category: <ul data-v-7be20f4f=""><li data-v-7be20f4f=""><a data-v-7be20f4f="" href="/w/%EB%B6%84%EB%A5%98:%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%
%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)" title="서은하(우아한 모녀)">서은하</a>와 <a class="wiki-link-internal" href="/w/%ED%99%8D%EC%9D%B8%EC%B2%A0" title="홍인철">홍인철</a>의 친딸</strong>로, <a class="wiki-link-internal" href="/w/%EC%BA%90%EB%A6%AC%20%EC%A0%95" title="캐리 정">캐리 정</a>이 <a class="wiki-link-internal" href="/w/%EC%B0%A8%EB%AF%B8%EC%97%B0(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)" title="차미연(우아한 모녀)">차미연</a>이었던 젊은 시절에 제이그룹에 대한 복수를 위해서 어린아이였던 유진을 유괴하는 바람에 생이별을 당한 것. 당시 서은하는 둘째인 홍세라를 낳기 위하여 진통을 겪고 있었는데, 하필이면 백화점에서 진통을 겪은 탓에 홍유라를 제대로 챙기지 못했다. 그 자리에서 구급대원들에게 실려갈 때에도 은하는 유라를 찾았지만, 결국 그 때 차미연이 유모차를 끌고 간 뒤 캐나다로 자취를 감췄다. <strong>즉, <a class="wiki-link-internal" href="/w/%ED%99%8D%EC%84%B8%EB%9D%BC" title="홍세라">홍세라</a>와는 친자매로 진짜 이름은 홍유라이다.</strong><a class="wiki-fn-content" href="#fn-1" title="여담으로 이 드라마와 같은 시기에 방영되는 주말드라마에서의 대법관 이름 또한 홍유라다."><span class="target" id="rfn-1"></span>[1]</a><br/><br/>물론 본인은 이 사실을 모르고 <strong>캐리정의 친딸이라 믿고 캐리정의 복수를 위해 자라나게 된다.</strong> 비록 엄마의 복수를 위한 도구처럼 되어버리고 삶이 행복하지 않은 것 같음에도 엄마를 위해선 감수해야한다는 목적으로 살아왔다. 참고로 어렸을때 캐나다에서 피팅룸에 갇힌 상태에서 캐리에게 버려졌다고 생각된 적이 있는데 이때 일때문에 폐소공포증이 생긴다.<a class="wiki-fn-content" href="#fn-2" title="이 점때문에 작중에서 자주 고생을 한다. 이 약점을 들켜 홍세라, 서은하 모녀에게 함정에 빠지기도 했을 정도. 하지만 오히려 이 약점때문에 3년전 기차에서 화장실에 갇혔을때 구해준이 구출해준 덕분에 서로 인연이 되는 시발점이 되기도 했다."><span class="target" id="rfn-2"></span>[2]</a> 그럼에도 엄마가 너무 힘들어서 버린 것이라며 이해해주고 원망을 안하려고 했을 정도로 엄마의 복수를 위한 삶을 다지면서 살았을 정도다.<br/><br/>여튼 캐리와 캐리 양자인 데니와 함께 한국으로 복수를 위해 돌아오고 먼저 구재명이 회장이 된 제이그룹에 천재 마케터로 스카우트 되어 입사한다. 그러면서 캐리가 할수 있는 복수의 기틀을 맡는 역할은 한다. 이뿐만이 아니다. 그가 하는 진짜 중요한 역할은 캐리의 복수를 위해 구재명의 아들 <a class="wiki-link-internal" href="/w/%EA%B5%AC%ED%95%B4%EC%A4%80" title="구해준">구해준</a>을 약혼자가 았는데도 유혹하는 것. 하지만 사실 <strong>구해준은 3년 전에 만나 좋아했던 남자였다.</strong> 그러나 알고보니 구해 ...
# -------------------------------------------content_paragraphs 끝---------------------------------------------
# 한유진(우아한 모녀)
#
#
# 우아한 모녀/등장인물드라마 히로인
#
#
# 한유진 / 제니스  한 / 홍유라배우: 차예련1. 개요2. 작중 행적3. 평가 제니스. 복수의 화신이 되어 사랑하는 남자까지도 복수의 도구로 이용했지만 결국 사랑 앞에, 또 다른 진실 앞에 무너져야 하는 그녀.차미연(캐리정)에 의해 유괴된 딸.폭풍같고 불같은 열정을 가슴에 품고 있는 여자.귀티나는 단아한 외모에 영민하고 깔끔한 성격.자존심이 강해 쉽게 곁을 주지않지만 한 번 마음을 준 상대에게는 한없이약한 성녀와 마녀 두 가지 모습을 가지고 있다.엄마의 기대에 부응하며 실력과 미모를 갖춘 재원으로 성장한 그녀. 거기에 엄마의 재력까지 더해져 그야말로 완벽 그 자체였다.누구나 인정하는 미모의 엘리트.하지만 그녀는 자신을 “복수를 위한 엄마의 걸작품”이라고 생각한다.엄마 앞에서 내색한적은 없다. 엄마의 딸로 태어난 이상, 그녀는 그 운명을 일찌감치 받아들이기로 했다. 그녀는 엄마를 사랑하는 착한 딸이니까.드라마 우아한 모녀의 등장인물로, 배우는 차예련.1990년생 (30세). 불 같은 열정을 가슴에 품고 있는 엘리트 중의 엘리트. 서은하와 홍인철의 친딸로, 캐리 정이 차미연이었던 젊은 시절에 제이그룹에 대한 복수를 위해서 어린아이였던 유진을 유괴하는 바람에 생이별을 당한 것. 당시 서은하는 둘째인 홍세라를 낳기 위하여 진통을 겪고 있었는데, 하필이면 백화점에서 진통을 겪은 탓에 홍유라를 제대로 챙기지 못했다. 그 자리에서 구급대원들에게 실려갈 때에도 은하는 유라를 찾았지만, 결국 그 때 차미연이 유모차를 끌고 간 뒤 캐나다로 자취를 감췄다. 즉, 홍세라와는 친자매로 진짜 이름은 홍유라이다.[1]물론 본인은 이 사실을 모르고 캐리정의 친딸이라 믿고 캐리정의 복수를 위해 자라나게 된다. 비록 엄마의 복수를 위한 도구처럼 되어버리고 삶이 행복하지 않은 것 같음에도 엄마를 위해선 감수해야한다는 목적으로 살아왔다. 참고로 어렸을때 캐나다에서 피팅룸에 갇힌 상태에서 캐리에게 버려졌다고 생각된 적이 있는데 이때 일때문에 폐소공포증이 생긴다.[2] 그럼에도 엄마가 너무 힘들어서 버린 것이라며 이해해주고 원망을 안하려고 했을 정도로 엄마의 복수를 위한 삶을 다지면서 살았을 정도다.여튼 캐리와 캐리 양자인 데니와 함께 한국으로 복수를 위해 돌아오고 먼저 구재명이 회장이 된 제이그룹에 천재 마케터로 스카우트 되어 입사한다. 그러면서 캐리가 할수 있는 복수의 기틀을 맡는 역할은 한다. 이뿐만이 아니다. 그가 하는 진짜 중요한 역할은 캐리의 복수를 위해 구재명의 아들 구해준을 약혼자가 았는데도 유혹하는 것. 하지만 사실 구해준은 3년 전에 만나 좋아했던 남자였다. 그러나 알고보니 구해준이 원수의 아들인걸 알게되자 괴로웠지만 어쩔 수 없어 떠난뒤 3년 후 돌아와서 복수를 진행한 것이다.[3] 유진도 이제는 원수의 아들이라며 마음을 다잡고 구해준을 유혹하기 시작한다. 심지어 3년 전 기억을 이용해 구해준을 더 애타게 만들고 자신을 끌리게 만든다. 결국 구해준은 넘아가게 되고 [4] 결국 약혼녀가 있는 구해준이 파혼까지 원하게 만든다.하지만 원래는 구해준에게 파혼뿐 아니라 파멸까지 몰고갈 계획이였다. 이때문에 구해준을 좋아했고 그에 따른 죄책감때문
 해치려고 한거아니냐는 오해까지 하게된다.[10] 다행히 캐리와는 갈등은 금방 풀렸고 캐리 말대로 제이그룹의 회장이 된다. 그뒤 구해준이 서은하에게 납치된 것을 알고 구해준을 찾아나서고 서은하 집에 옮긴 것을 알고 경찰에 신고해 구출한다. 구해준이 깨어나자 서로 사랑을 확인하면서 이제는 정식으로 커플이 되었다. 그러면서 빨리 결혼하자는 조윤경의 말을 듣고 결혼 준비를 하게된다.하지만 결혼 준비를 하면서 자꾸 이상한 걸 듣거나 이상한 일을 겪는다. 먼저 가짜 홍유라인 김희정에게 구해준의 친모가 조윤경이 아니고 아이가 바뀌었다는 소식도 들었고, 그 가짜 홍유라를 심은 사람이 자신의 엄마인 캐리인 것도 알게되어 경악한다. 캐리에게 묻자 복수를 위해서 그랬다고 말했지만 아무리 복수의 대상이라도 그렇게까지 한 캐리의 의도를 몰라 답답해한다. 심지어 자신을 그토록 싫어하던 서은하와 홍인철이 찾아와 결혼을 말리는데 오히려 화내는게 아니라 눈물로 호소하는 모습을 보고 갑작스럽게 바뀐 그들의 모습을 이해하지 못한다. 또 구해준과 캐리가 서로 자신이 모르는 비밀을 숨기고 있다는 생각도 든다. 그래도 사랑하는 구해준과 결혼을 앞두고 있기기에 결혼식 준비도 하고 캐리와 같이 모녀여행도 다니는 등 행복하게 결혼을 기대하며 하루하루를 보내고 있었다.그러나 89회에서 결혼식 전날에 유학간줄 알았던 홍세라에게 전화오게되는데 모든 진실을 알려주겠다며 하자 만나게 된다. 이때 홍세라에게 한유진 본인이 홍유라고 그 홍유라인 자신을 캐리가 유괴한거며 구해준이 캐리 친아들라는 얘기를 듣는다. 당연히 말도 안되는 소리라며 떠나려 하지만 홍세라가 증거물을 보여주는데 그 증거물이  서은하와 자신이 모녀라는 유전자 검사지였다. 믿지 못하지만 홍세라가 홍인철, 서은하가 자신을 찾아갔던 것을 다시 상기시켜주자 그제서야 자신이 느꼈던 수많은 의문들이 풀리면서 자신과 캐리, 구해준의 정체를 깨닫고 패닉에 빠져버린다. 집으로 다시 돌아올때는 여전히 충격에 새벽까지 잠을 이루지 못하다가 누군가에게 전화를 하고[11] 결혼식에 간다. 그러나 결혼식 ...

# %%
req.url
# Out:
# 'https://namu.wiki/w/%ED%95%9C%EC%9C%A0%EC%A7%84(%EC%9A%B0%EC%95%84%ED%95%9C%20%EB%AA%A8%EB%85%80)'

# %% [markdown]
# - find 함수 관련 자료
#   - https://oolaf.tistory.com/78
#   - https://m.cafe.daum.net/flowlife/RUrO/42?q=D_MCiUSfMukTI0&

# %% [markdown]
# -----

# %% [markdown]
# ### [나무위키 최근변경 데이터 크롤링]

# %%
import pandas as pd
data_i = [1,2,3]

df_i=pd.DataFrame(data_i, columns=['no'])

df_i
# Out:
#    no
# 0   1
# 1   2
# 2   3

# %%
# 크롤링한 데이터를 데이터 프레임으로 만들기 위해 준비합니다.
columns = ['title', 'category', 'content_text']
df = pd.DataFrame(columns=columns)

# 각 페이지별 '제목', '카테고리', '본문' 정보를 데이터 프레임으로 만듭니다.
for page_url in page_urls:

    # 사이트의 html 구조에 기반하여 크롤링을 수행합니다.
    req = requests.get(page_url)
    html = req.content
    soup = BeautifulSoup(html, 'lxml')
    contents_table = soup.find(name="article")
    
    title = contents_table.find_all('h1')[0]
    category = contents_table.find_all('ul')[0]
    content_paragraphs = contents_table.find_all(name="div", attrs={"class":"wiki-paragraph"})
    
    content_corpus_list = []
    
    # 페이지 내 제목 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if title is not None:
        row_title = title.text.replace("\n", " ")
    else:
        row_title = ""
    
    # 페이지 내 본문 정보에서 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if content_paragraphs is not None:
        for paragraphs in content_paragraphs:
            if paragraphs is not None:
                content_corpus_list.append(paragraphs.text.replace("\n", " "))
            else:
                content_corpus_list.append("")
    else:
        content_corpus_list.append("")
        
    # 페이지 내 카테고리정보에서 “분류”라는 단어와 개행 문자를 제거한 뒤 추출합니다. 만약 없는 경우, 빈 문자열로 대체합니다.
    if category is not None:
        row_category = category.text.replace("\n", " ")
    else:
        row_category = ""
    
    # 모든 정보를 하나의 데이터 프레임에 저장합니다.
    row = [row_title, row_category, "".join(content_corpus_list)]
    series = pd.Series(row, index=df.columns)
    df = df.append(series, ignore_index=True)

# %%
df.head(5)
# Out:
#           title            category  \
# 0  한유진(우아한 모녀)   우아한 모녀/등장인물드라마 히로인
# 1     대학 간 통폐합                  대학교
# 2       슬리피 토드      스타폭스 시리즈개구리 캐릭터
# 3     스틱 엠파이어즈               플래시 게임
# 4         리고모르                  엘소드
#
#                                         content_text
# 0  한유진 / 제니스  한 / 홍유라배우: 차예련1. 개요2. 작중 행적3. 평가 제니...
# 1  1. 개요2. 통합 사례2.1. 국공립대학2.2. 사립대학3. 통합 논의 및 루머4...
# 2  스 타 폭 스  유 격 대원 년 대 원폭스 맥클라우드팔코 람바디슬리피 토드페피 헤어...
# 3  스틱 엠파이어즈 Stick Empires 하는곳 : http://www.sticke...
# 4    관련 정보 [ 펼치기 · 접기 ]시스템장비 · 레어 아바타 · 악세사리 · 칭호...

# %% [markdown]
# -----

# %% [markdown]
# # <Step2. 추출> : 키워드 추출

# %% [markdown]
# ### [텍스트 데이터 전처리]

# %% [markdown]
# #### re모듈
#   - re는 Regular Expression(정규표현식)의 약자
#   - 파이썬에서 제공하는 정규표현식 라이브러리
#
#
#   -  프로세스-->
#
#      - i) p = re.compile('정규표현식')을 통해서 정규표현식을 컴파일
#
#      - ii) 컴파일된 패턴 객체(p)를 이용하여 이 객체가 가지고 있는 메서드를 통해 작업을 수행할 수 있다.

# %%
from IPython.display import Image

Image("5.jpg")
 #https://python.bakyeono.net/chapter-11-2.html

# %%
# 텍스트 정제 함수 : 한글 이외의 문자는 전부 제거합니다.
def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+') # 한글의 정규표현식을 나타냅니다.
    result = hangul.sub('', text)
    return result

# %%
print(type(df['content_text'][0]))
print(df['content_text'][0])
# Out:
# <class 'str'>
# 한유진 / 제니스  한 / 홍유라배우: 차예련1. 개요2. 작중 행적3. 평가 제니스. 복수의 화신이 되어 사랑하는 남자까지도 복수의 도구로 이용했지만 결국 사랑 앞에, 또 다른 진실 앞에 무너져야 하는 그녀.차미연(캐리정)에 의해 유괴된 딸.폭풍같고 불같은 열정을 가슴에 품고 있는 여자.귀티나는 단아한 외모에 영민하고 깔끔한 성격.자존심이
더더욱 미안한 마음이 들 뿐이다. 그러나 캐리에게도 3년 전 구해준의 그 여자가 본인이였다는 것까지 들켜 캐리가 믿지 못하기때문에 걱정시키고 싶지 않아 어떻게든 마음을 다잡는다. 복수 과정에서 서은하나 홍세라 등에게 뺨을 맞거나 머리챙이 잡히는 등 별별 일이 다 있어도 가족을 위한다는 마음 그 하나로 꿋꿋이 구해준을 복수의 대상으로 생각하며 유혹한다. 결국 구해준이 헤어지자고 한 날[6] 마지막을 같이 보내자고 하고 둘이 함께 밤을 보낸뒤 뒤통수쳐 성폭행범으로까지 몰리게 한다. 이후 구해준에게 연락을 끊고 혼란스러워하는 구해준을 길에서 우연히 마주치었을때도 복수하기 위해 그랬다며 매몰차게 대한다. 그렇지만 결국 그도 구해준을 사랑했었는지 성폭행범까지 몰리게 만든 자신을 자해하며 자책하고 급기야 자살시도까지 할정도로 멘탈이 붕괴되었다.[7]하지만 이내 마음을 다시 되찾고 결국 복수를 계속 진행해야겠다는 마음을 다잡으며 캐리 정의 계획대로 다시 제이 그룹의 본부장으로 등장해 복수를 진행해 나간다. 당연히 구해준 입장에선 이리 등장한 제니스에 대해 배신감이 들수 밖에 없기에 구해준과 서로 대립하기도 하지만 그럼에도 구해준에 대한 미안함과 미련은 묘하게 남는 듯한 모습을 보여주었다. 무엇보다 자신에게 헤어지자고 한 이유도 구해준이 서은하에게 친아버지가 아닌 사실을 들어서 그런 것도 듣게 되며 그런 마음이 더 커진다.[8]그러던 중 캐리가 자신이 복수하러 온것을 밝히고 난 뒤에 캐리가 서은하에게 홍유라 유괴범이라는 오해를 받는 것을 알게된다. 이때문에 엄마인 자신의 오해를 풀기 위해 홍유라에 대해서도 알아보기도 하고 그러지만 캐리는 오히려 자신을 캐나다로 돌려보내려하고 홍유라를 관심갖는 것에 왜 찾나며 지나치게 민감하게 반응하는 것을 보고 이해하지 못한다. 그래도 그는 엄마 곁에 있어야겠다며 구재명이 자신을 고소하려고하자 캐나라로 돌아가려한것도 오히러 자신이 자수해 한국에 머무르려고 할 정도로 캐리 곁을 지켜주려고 한다. 캐리가 홍유라인 자신을 유괴했을거라는 생각은 절대 하지못한채.이렇게 복수를 진행하다가 구재명 사임건을 놓고 진행하는 주주총회에서 캐리와 함께 구재명 가문을 완전 박살내[9] 풍비박산으로 만들어버린다. 이 때 만난 구해준이 캐리와 제니스의 복수 끝이 행복했으면 좋겠다고 빌어주자 자신이 행복할 수 있을까하며 구해준에 대한 미안함만 남아나는데 하필 그날 조윤경을 구하려던 구해준이 교통사고를 당했다는 소식을 그 다음날 듣게된다. 충격을 받음과 동시에 자신이 그동안 구해준에 한 짓에 대한 죄책감과 함께 구해준을 진심으로 사랑하고 있음을 깨달음으로써 구해준에 병실에 매일 찾아간다. 이때문에 회장직을 오르지 않겠다며 캐리와 갈등을 겪기도 하고, 심지어 구해준의 병실을 찾아가다가 캐리가 구해준을 해치려고 한거아니냐는 오해까지 하게된다.[10] 다행히 캐리와는 갈등은 금방 풀렸고 캐리 말대로 제이그룹의 회장이 된다. 그뒤 구해준이 
는데 오히려 화내는게 아니라 눈물로 호소하는 모습을 보고 갑작스럽게 바뀐 그들의 모습을 이해하지 못한다 또 구해준과 캐리가 서로 자신이 모르는 비밀을 숨기고 있다는 생각도 든다 그래도 사랑하는 구해준과 결혼을 앞두고 있기기에 결혼식 준비도 하고 캐리와 같이 모녀여행도 다니는 등 행복하게 결혼을 기대하며 하루하루를 보내고 있었다그러나 회에서 결혼식 전날에 유학간줄 알았던 홍세라에게 전화오게되는데 모든 진실을 알려주겠다며 하자 만나게 된다 이때 홍세라에게 한유진 본인이 홍유라고 그 홍유라인 자신을 캐리가 유괴한거며 구해준이 캐리 친아들라는 얘기를 듣는다 당연히 말도 안되는 소리라며 떠나려 하지만 홍세라가 증거물을 보여주는데 그 증거물이  서은하와 자신이 모녀라는 유전자 검사지였다 믿지 못하지만 홍세라가 홍인철 서은하가 자신을 찾아갔던 것을 다시 상기시켜주자 그제서야 자신이 느꼈던 수많은 의문들이 풀리면서 자신과 캐리 구해준의 정체를 깨닫고 패닉에 빠져버린다 집으로 다시 돌아올때는 여전히 충격에 새벽까지 잠을 이루지 못하다가 누군가에게 전화를 하고 결혼식에 간다 그러나 결혼식 준비과정에서도 시종일관 어두운 표정이더니 결국 신부 입장 하기전에 뛰쳐나가버린다 아직도 충격이 가시지 않는지 비틀거리며 이곳저곳 거리를 떠돈다 이때문에 중간에 쓰러져서 잠시 병원에 실려오기도 했다가 나가는 등 심신이 모두 안정되지 않는 모습이였다 결국 ...

# %%
df.head(5)
# Out:
#           title            category  \
# 0  한유진(우아한 모녀)   우아한 모녀/등장인물드라마 히로인
# 1     대학 간 통폐합                  대학교
# 2       슬리피 토드      스타폭스 시리즈개구리 캐릭터
# 3     스틱 엠파이어즈               플래시 게임
# 4         리고모르                  엘소드
#
#                                         content_text
# 0  한유진 / 제니스  한 / 홍유라배우: 차예련1. 개요2. 작중 행적3. 평가 제니...
# 1  1. 개요2. 통합 사례2.1. 국공립대학2.2. 사립대학3. 통합 논의 및 루머4...
# 2  스 타 폭 스  유 격 대원 년 대 원폭스 맥클라우드팔코 람바디슬리피 토드페피 헤어...
# 3  스틱 엠파이어즈 Stick Empires 하는곳 : http://www.sticke...
# 4    관련 정보 [ 펼치기 · 접기 ]시스템장비 · 레어 아바타 · 악세사리 · 칭호...

# %%
# 각 피처마다 데이터 전처리를 적용합니다.
df['title'] = df['title'].apply(lambda x: text_cleaning(x))
df['category'] = df['category'].apply(lambda x: text_cleaning(x))
df['content_text'] = df['content_text'].apply(lambda x: text_cleaning(x))
df.head(5)
# Out:
#         title           category  \
# 0  한유진우아한 모녀   우아한 모녀등장인물드라마 히로인
# 1   대학 간 통폐합                 대학교
# 2     슬리피 토드     스타폭스 시리즈개구리 캐릭터
# 3   스틱 엠파이어즈              플래시 게임
# 4       리고모르                 엘소드
#
#                                         content_text
# 0  한유진  제니스  한  홍유라배우 차예련 개요 작중 행적 평가 제니스 복수의 화신이...
# 1   개요 통합 사례 국공립대학 사립대학 통합 논의 및 루머 유사 사례 국립대 통합네트...
# 2  스 타 폭 스  유 격 대원 년 대 원폭스 맥클라우드팔코 람바디슬리피 토드페피 헤어...
# 3  스틱 엠파이어즈   하는곳          우리의 백성들은 학살당했고 우리의 고향은...
# 4    관련 정보  펼치기  접기 시스템장비  레어 아바타  악세사리  칭호 일람  스...

# %% [markdown]
# -----

# %%
Image("6.jpg")
#https://wikidocs.net/46758

# %% [markdown]
# ### [말뭉치 만들기]

# %%
df.head(5)
# Out:
#         title           category  \
# 0  한유진우아한 모녀   우아한 모녀등장인물드라마 히로인
# 1   대학 간 통폐합                 대학교
# 2     슬리피 토드     스타폭스 시리즈개구리 캐릭터
# 3   스틱 엠파이어즈              플래시 게임
# 4       리고모르                 엘소드
#
#                                         content_text
# 0  한유진  제니스  한  홍유라배우 차예련 개요 작중 행적 평가 제니스 복수의 화신이...
# 1   개요 통합 사례 국공립대학 사립대학 통합 논의 및 루머 유사 사례 국립대 통합네트...
# 2  스 타 폭 스  유 격 대원 년 대 원폭스 맥클라우드팔코 람바디슬리피 토드페피 헤어...
# 3  스틱 엠파이어즈   하는곳          우리의 백성들은 학살당했고 우리의 고향은...
# 4    관련 정보  펼치기  접기 시스템장비  레어 아바타  악세사리  칭호 일람  스...

# %%
print(df['title'])
print("----------------------")
print(type(df['title']))
# Out:
# 0     한유진우아한 모녀
# 1      대학 간 통폐합
# 2        슬리피 토드
# 3      스틱 엠파이어즈
# 4          리고모르
#          ...
# 67      리들러 챌린지
# 68          손성씨
# 69           이라
# 70           정우
# 71           내한
# Name: title, Length: 72, dtype: object
# ----------------------
# <class 'pandas.core.series.Series'>

# %%
# 각 피처마다 말뭉치를 생성합니다.
#title_corpus = "".join(df['title'])
title_corpus = "".join(df['title'].tolist())
content_corpus = "".join(df['content_text'].tolist())
print(title_corpus)
# Out:
# 한유진우아한 모녀 대학 간 통폐합 슬리피 토드 스틱 엠파이어즈 리고모르        가면라이더 크로노스 크리스티앙 카바셀레 멜론웹사이트하트수 순위 벨 로즈 전지적 독자 시점 바이오하자드  플래닛 주시나리오 남북통일 창원시인물 엠파이어 토탈 워연합주 이츠카 코토리 영등포구 나카무라 슈고 정지소 동방제국사 서주 대학살 히로시마나가사키 원자폭탄 투하 서윤카운터사이드  피겨 스케이팅 전일본선수권 대회 경주 버스   연오 앵지 아케디아   안티 히어로 비사문천 자오폴아웃  마스터로드 중국인 캐릭터 웅지세무대학교 라스타칸의 대난투 쿠와야마 치유키  동로마 제국 트와이스나의 히어로 아카데미아 해피 레인 야마시로 유이 내일은 미스터트롯 파일성지패식 수페르비아 타카스기 신사쿠 니클라스 클라분데 마인크래프트팁 문명 자연경관 이채연 제대 국회의원 선거후보자 흑기사 키레나이카 범규 쿠와야마 치유키카드 가이런닝맨 카운터사이드사원 오리진 노민우 고소카페 이단심문사건 왕자영요아이템 애디슨 리드 인비디아 용서받지 못한 자한국 영화 프리티 리듬 시리즈그룹 목록 스패로우카운터사이드 리들러 챌린지 손성씨 이라 정우 내한

# %%
Image("7.jpg")
#https://ourcstory.tistory.com/46

# %% [markdown]
# -----

# %% [markdown]
# ### [konlpy를 이용한 키워드 추출]

# %% [markdown]
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
# - 아래의 방법으로 설치해도 실행되지 않는다면, http://konlpy.org/ko/latest/install/ 를 참고하세요.
#     - Install
#         - 1. Java를 설치합니다. (https://java.com/ko/download/)
#         - 2. c++ 컴파일러를 설치합니다.
#             - 윈도우 : `Microsoft Visual C++ 14.0` 설치 권장, https://visualstudio.microsoft.com/ko/downloads/
#             - Mac OS : `Xcode` 설치 권장
#             - Linux : `gcc` 설치 권장
#         - 3. 아래와 같은 파이썬 패키지를 설치합니다.
#             - (env_name) `pip install konlpy`
#             - (env_name) `pip install jpype1`
#             - (env_name) `pip install Jpype1-py3`

# %%
from konlpy.tag import Okt
from collections import Counter

# konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(content_corpus)
count = Counter(nouns)

#https://ellun.tistory.com/46
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-51a508fb7533> in <module>
#       3
#       4 # konlpy의 형태소 분석기로 명사 단위의 키워드를 추출합니다.
# ----> 5 nouns_tagger = Okt()
#       6 nouns = nouns_tagger.nouns(content_corpus)
#       7 count = Counter(nouns)
#
# ~\Anaconda3\lib\site-packages\konlpy\tag\_okt.py in __init__(self, jvmpath, max_heap_size)
#      89     def __init__(self, jvmpath=None, max_heap_size=1024):
#      90         if not jpype.isJVMStarted():
# ---> 91             jvm.init_jvm(jvmpath, max_heap_size)
#      92
#      93         oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#
# ~\Anaconda3\lib\site-packages\konlpy\jvm.py in init_jvm(jvmpath, max_heap_size)
#      53     classpath = os.pathsep.join(f.format(*args) for f in folder_suffix)
#      54
# ---> 55     jvmpath = jvmpath or jpype.getDefaultJVMPath()
#      56
#      57     # NOTE: Temporary patch for Issue #76. Erase when possible.
#
# ~\Anaconda3\lib\site-packages\jpype\_core.py in get_default_jvm_path()
#     138     :raise ValueError: No JVM library found
#     139     """
# --> 140     return get_jvm_finder().get_jvm_path()
#     141
#     142 # Naming compatibility
#
# ~\Anaconda3\lib\site-packages\jpype\_jvmfinder.py in get_jvm_path(self)
#     110             raise ValueError("No JVM shared library file ({0}) found. "
#     111                              "Try setting up the JAVA_HOME environment "
# --> 112                              "variable properly.".format(self._libfile))
#     113
#     114     def _get_from_java_home(self):
#
# ValueError: No JVM shared library file (jvm.dll) found. Try setting up the JAVA_HOME environment variable properly.

# %% [markdown]
# ##### 1. Okt객체의 noun 메소드
#
# : 'text'에서 명사만 분리/추출하며, 결과 값으로 순환 가능한 객체를 반환
#
# ##### 2. Counter객체
#
# :  counting hashable container 객체로서 간단히 말해, 빈도수 계산을 위한 사전형태의 데이터

# %%
from IPython.display import Image

Image("8.jpg")

#https://cceeddcc.tistory.com/8 ->
#https://konlpy-ko.readthedocs.io/ko/v0.4.3/morph/#comparison-between-pos-tagging-classes -> 형태소분석기간 비교
# https://soyoung-new-challenge.tistory.com/31 -> Okt 형태소분석기에 대한 디테일한 설명
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _repr_mimebundle_(self, include, exclude)
#    1242         if self.embed:
#    1243             mimetype = self._mimetype
# -> 1244             data, metadata = self._data_and_metadata(always_both=True)
#    1245             if metadata:
#    1246                 metadata = {mimetype: metadata}
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1251     def _data_and_metadata(self, always_both=False):
#    1252         """shortcut for returning metadata with shape information, if defined"""
# -> 1253         b64_data = b2a_base64(self.data).decode('ascii')
#    1254         md = {}
#    1255         if self.metadata:
#
# TypeError: a bytes-like object is required, not 'str'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _repr_png_(self)
#    1268     def _repr_png_(self):
#    1269         if self.embed and self.format == self._FMT_PNG:
# -> 1270             return self._data_and_metadata()
#    1271
#    1272     def _repr_jpeg_(self):
#
# ~\Anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1251     def _data_and_metadata(self, always_both=False):
#    1252         """shortcut for returning metadata with shape information, if defined"""
# -> 1253         b64_data = b2a_base64(self.data).decode('ascii')
#    1254         md = {}
#    1255         if self.metadata:
#
# TypeError: a bytes-like object is required, not 'str'

# %%
count
# Out:
# Counter({'찌르레기': 16,
#          '이명': 10,
#          '분류': 53,
#          '동물계': 3,
#          '척삭동물문': 3,
#          '강조': 24,
#          '강목': 3,
#          '참새목': 3,
#          '속': 191,
#          '종': 20,
#          '멸종': 2,
#          '위기': 37,
#          '등급': 54,
#          '관심': 48,
#          '필요': 90,
#          '과': 164,
#          '조류': 2,
#          '시베리아': 5,
#          '사할린': 1,
#          '섬': 29,
#          '쿠릴': 1,
#          '열도': 1,
#          '만주': 6,
#          '등지': 10,
#          '서식': 6,
#          '개요': 105,
#          '특징': 49,
#          '모티브': 37,
#          '캐릭터': 289,
#          '편집': 1206,
#          '크기': 43,
#          '약': 54,
#          '머리': 119,
#          '날개': 37,
#          '빛': 34,
#          '더': 458,
#          '얼굴': 75,
#          '눈': 97,
#          '주위': 30,
#          '깃털': 5,
#          '몸': 92,
#          '아래쪽': 3,
#          '회색': 4,
#          '꽁': 1,
#          '편이': 174,
#          '식물': 6,
#          '열매': 44,
#          '지렁이': 1,
#          '먹이': 7,
#          '인간': 67,
#          '재배': 2,
#          '곡물': 2,
#          '닥치고': 1,
#          '새': 33,
#          '취급': 61,
#          '사냥': 11,
#          '때': 897,
#          '떼': 12,
#          '토네이도': 2,
#          '형태': 52,
#          '형성': 23,
#          '모습': 405,
#          '장관': 17,
#          '환상': 10,
#          '군무': 4,
#          '이유': 216,
#          '동료': 108,
#          '수': 1686,
#          '포식자': 2,
#          '공격': 628,
#          '위': 427,
#          '해': 77,
#          '지기': 5,
#          '직전': 42,
#          '가장': 285,
#          '쓰레기': 8,
#          '성격': 88,
#          '깡패': 9,
#          '이름': 344,
#          '값': 18,
#          '뻐꾸기': 3,
#          '자기': 126,
#          '둥지': 15,
#          '탁란': 4,
#          '대부분': 159,
#          '남': 54,
#          '새끼': 14,
#          '자신': 536,
#          '민폐': 8,
#          '알': 255,
#          '밖': 27,
#          '주인': 22,
#          '나중': 38,
#          '다시': 185,
#          '미리': 30,
#          '협박': 22,
#          '후': 434,
#          '진짜': 51,
#          '보복': 8,
#          '깽판': 2,
#          '적반하장': 2,
#          '하진': 4,
#          '걸': 177,
#          '생각': 303,
#          '악질': 5,
#          '다그': 22,
#          '대로': 29,
#          '골칫': 1,
#          '덩어리': 13,
#          '쥐라': 1,
#          '멸칭': 1,
#          '쥐매': 1,
#          '교육': 101,
#          '울음소리': 7,
#          '기도': 99,
#          '번식': 7,
#          '기': 316,
#          '큐리': 2,
#          '리리': 5,
#          '상술': 15,
#          '안': 356,
#          '이미지': 98,
#          '별개': 22,
#          '말': 712,
#          '음': 36,
#          '높낮이': 1,
#          '등': 961,
#          '소리': 94,
#          '흉내': 8,
#          '낼': 37,
#          '교감': 1,
#          '특성': 103,
#          '때문': 1009,
#          '모차르트': 5,
#          '애완동물': 2,
#          '돈': 74,
#          '가계부': 2,
#          '년': 1505,
#          '월': 875,
#          '일': 683,
#          '오스트리아': 4,
#          '빈': 15,
#          '거리': 112,
#          '애완': 2,
#          '마리': 45,
#          '구입': 38,
#          '것': 2453,
#          '기록': 150,
#          '이': 1281,
#          '산': 46,
#          '앞': 157,
#          '초': 196,
#          '그': 1200,
#          '세상': 24,
#          '피아노': 5,
#          '협주곡': 2,
#          '번': 251,
#          '악장': 1,
#          '테마': 15,
#          '노래': 35,
#          '절': 19,
#          '악보': 2,
#          '감탄': 3,
#          '슈퍼히어로': 2,
#          '포켓몬스터': 5,
#          '시리즈': 194,
#          '찌르꼬': 1,
#          '앵그리버드': 22,
#          '버블': 19,
#          '구름': 2,
#          '정체': 33,
#          '뉴스': 17,
#          '마피아': 26,
#          '연합뉴스': 1,
#          '관련': 212,
#          '문서': 208,
#          '스타크래프트': 33,
#          '공허': 201,
#          '유산': 22,
#          '협동': 27,
#          '전': 436,
#          '임무': 52,
#          '상위': 65,
#          '제라툴': 248,
#          '하위': 32,
#          '사령관': 155,
#          '대사': 94,
#          '조합': 70,
#          '및': 263,
#          '궁합': 13,
#          '목록': 45,
#          '종족': 69,
#          '별': 57,
#          '출시일': 3,
#          '순': 19,
#          '테란': 41,
#          '프로토스': 45,
#          '레이': 152,
#          '케리': 17,
#          '건': 193,
#          '아르타': 11,
#          '니스': 14,
#          '스완': 13,
#          '라보': 9,
#          '준': 73,
#          '노바': 21,
#          '아바': 18,
#          '투르': 10,
#          '카': 176,
#          '락스': 21,
#          '한과': 5,
#          '호': 61,
#          '스투코': 5,
#          '프': 19,
#          '알라': 14,
#          '라크': 8,
#          '타이': 15,
#          '스데': 1,
#          '하카': 9,
#          '피닉스': 19,
#          '업그레이드': 112,
#          '능력': 600,
#          '상단': 11,
#          '패널': 73,
#          '유물': 309,
#          '보관': 17,
#          '소': 36,
#          '군단': 94,
#          '텔': 28,
#          '브루스': 25,
#          '조': 30,
#          '세르': 20,
#          '다스': 23,
#          '첫': 102,
#          '조각': 137,
#          '정지': 25,
#          '광선': 36,
#          '테서랙트': 77,
#          '초석': 46,
#          '억압': 17,
#          '수정': 64,
#          '두': 195,
#          '지원': 139,
#          '행렬': 9,
#          '점멸': 114,
#          '세': 157,
#          '형체': 19,
#          '화신': 53,
#          '정수': 22,
#          '마스터': 58,
#          '힘': 185,
#          '유닛': 407,
#          '고대': 31,
#          '연결': 59,
#          '체': 69,
#          '젤나가': 175,
#          '선도': 10,
#          '통로': 29,
#          '복자': 50,
#          '방패': 52,
#          '호기': 31,
#          '기사': 138,
#          '피조': 34,
#          '물': 116,
#          '시설': 60,
#          '집행자': 44,
#          '중': 765,
#          '재기': 23,
#          '전송': 105,
#          '감시자': 37,
#          '건물': 150,
#          '연구': 65,
#          '핵': 26,
#          '제련소': 22,
#          '구축': 28,
#          '원소': 50,
#          '방어': 222,
#          '포': 81,
#          '기타': 72,
#          '융': 10,
#          '화소': 20,
#          '평가': 205,
#          '장점': 47,
#          '단점': 74,
#          '평': 45,
#          '운영': 215,
#          '업적': 20,
#          '로딩': 4,
#          '일러스트': 27,
#          '소개': 68,
#          '동영상': 30,
#          '암흑': 50,
#          '정': 47,
#          '무관': 29,
#          '숙련': 11,
#          '플레이어': 48,
#          '추천': 31,
#          '조종': 39,
#          '병력': 101,
#          '강화': 142,
#          '전사': 198,
#          '예언': 24,
#          '시야': 60,
#          '전장': 42,
#          '도움': 78,
#          '전설': 54,
#          '개': 211,
#          '하나': 328,
#          '소환': 161,
#          '궁극': 50,
#          '제한': 64,
#          '시간': 329,
#          '동안': 140,
#          '전투': 248,
#          '주요': 45,
#          '등장인물': 67,
#          '이자': 105,
#          '모든': 201,
#          '동족': 3,
#          '아몬': 5,
#          '구원': 12,
#          '네': 41,
#          '짐': 20,
#          '참전': 12,
#          '블리즈컨': 3,
#          '발표': 29,
#          '영웅': 69,
#          '사용': 532,
#          '발굴': 12,
#          '창조': 23,
#          '스킬': 250,
#          '시작': 245,
#          '최대': 115,
#          '보급': 28,
#          '품': 26,
#          '동시': 88,
#          '정예': 29,
#          '컨셉': 41,
#          '등장': 377,
#          '광전사': 18,
#          '생산': 83,
#          '기본': 247,
#          '추적자': 18,
#          '점도': 14,
#          '특이': 5,
#          '사항': 88,
#          '또한': 303,
#          '기와': 20,
#          '타': 157,
#          '일반': 129,
#          '구성': 70,
#          '부대': 94,
#          '고정': 53,
#          '색상': 13,
#          '남옥': 1,
#          '내용': 175,
#          '참고': 128,
#          '단계': 35,
#          '구도': 43,
#          '그림자': 45,
#          '가용': 1,
#          '감시': 16,
#          '자가용': 2,
#          '테': 70,
#          '랙트': 14,
#          '레벨': 134,
#          '명칭': 52,
#          '효과': 174,
#          '의': 332,
#          '보유': 49,
#          '생명력': 18,
#          '탑': 70,
#          '동력': 27,
#          '직접': 147,
#          '건설': 51,
#          '자동': 65,
#          '실현': 9,
#          '마지막': 121,
#          '발견': 130,
#          '다음': 133,
#          '사이오닉': 39,
#          '신인': 30,
#          '진화': 29,
#          '추가': 202,
#          '이용': 184,
#          '잔': 32,
#          '상이': 9,
#          '남아': 20,
#          '적': 387,
#          '무기': 120,
#          '해당': 191,
#          '피해': 244,
#          '에너지': 41,
#          '재생': 22,
#          '속도': 221,
#          '증가': 104,
#          '이동': 141,
#          '경로': 15,
#          '상의': 45,
#          '대상': 136,
#          '위치': 131,
#          '투영': 29,
#          '중재': 25,
#          '로봇': 12,
#          '분열': 20,
#          '정화': 21,
#          '폭발': 83,
#          '광역': 54,
#          '지상': 79,
#          '대한': 326,
#          '선택': 129,
#          '배치': 41,
#          '기절': 47,
#          '막': 155,
#          '대공': 35,
#          '공중': 79,
#          '뒤': 304,
#          '휘': 28,
#          '피해량': 60,
#          '재사용': 82,
#          '감소': 125,
#          '집정관': 13,
#          '인터페이스': 1,
#          '지시': 32,
#          '파괴': 83,
#          '인근': 21,
#          '비': 183,
#          '활성화': 44,
#          '휘하': 7,
#          '환류': 10,
#          '흡수': 48,
#          '돌진': 22,
#          '요격': 3,
#          '라야': 16,
#          '포격기': 17,
#          '분광': 12,
#          '사거리': 80,
#          '계속': 146,
#          '혼돈': 31,
#          '폭풍': 44,
#          '범위': 77,
#          '내의': 12,
#          '일시': 17,
#          '비행': 19,
#          '웜홀': 14,
#          '생': 75,
#          '성기': 3,
#          '사이': 128,
#          '망': 32,
#          '측정': 10,
#          '예측': 23,
#          '회': 214,
#          '충전': 54,
#          '재': 60,
#          '오라': 28,
#          '투': 31,
#          '사체': 20,
#          '를': 292,
#          '반사': 34,
#          '치명': 29,
#          '보호': 191,
#          '대리인': 5,
#          '비용': 132,
#          '로': 215,
#          '쌍': 7,
#          '발동': 104,
#          '모두': 278,
#          '회복': 99,
#          '각각': 41,
#          '모드': 67,
#          '작동': 8,
#          '초당': 15,
#          '만큼': 94,
#          '완벽': 4,
#          '소형': 13,
#          '하급': 5,
#          '퇴화': 13,
#          '의지': 35,
#          '치': 97,
#          '속성': 56,
#          '장갑': 103,
#          '기계': 41,
#          '조물': 25,
#          '설명': 166,
#          '수집': 37,
#          '총': 169,
#          '가지': 248,
#          '제외': 112,
#          '나머지': 60,
#          '종류': 37,
#          '해금': 20,
#          '고용': 17,
#          '무법자': 2,
#          '중간': 47,
#          '타이커스': 11,
#          '한번': 58,
#          '공세': 59,
#          '고려': 43,
#          '곳': 242,
#          '게임': 186,
#          '시': 226,
#          '태양': 22,
#          '유령': 8,
#          '사관학교': 3,
#          '데': 140,
#          '굴': 18,
#          '부활': 44,
#          '고유': 20,
#          '그냥': 145,
#          '장식': 10,
#          '무적': 17,
#          '상태': 230,
#          '기능': 52,
#          '의미': 112,
#          '여기': 184,
#          '역할': 83,
#          '률': 26,
#          '그다지': 23,
#          '일도': 13,
#          '사족': 5,
#          '옆': 71,
#          '못': 245,
#          '버그': 29,
#          '인식': 68,
#          '실제': 217,
#          '충돌': 28,
#          '커서': 13,
#          '추정': 62,
#          '현재': 213,
#          '소의': 14,
#          '제대로': 120,
#          '문제': 315,
#          '해결': 63,
#          '광물': 24,
#          '소비': 13,
#          '여러': 104,
#          '증원': 4,
#          '최초': 65,
#          '지점': 29,
#          '지정': 27,
#          '설정': 96,
#          '방식': 81,
#          '전반': 32,
#          '스펙': 19,
#          '수가': 54,
#          '결과': 124,
#          '영향': 70,
#          '요구': 102,
#          '통해': 160,
#          '여타': 8,
#          '라면': 100,
#          '어디': 72,
#          '향': 80,
#          '스스로': 35,
#          '역시': 160,
#          '시전': 74,
#          '제어': 23,
#          '지속': 106,
#          '유도': 25,
#          '어택': 17,
#          '땅': 56,
#          '조작': 49,
#          '눈앞': 9,
#          '중립': 7,
#          '구별': 3,
#          '내': 187,
#          '아군': 64,
#          '절반': 26,
#          '초로': 6,
#          '전체': 110,
#          '정도': 596,
#          '성능': 86,
#          '즉': 138,
#          '위급': 2,
#          '상황': 315,
#          '타개': 5,
#          '거나': 106,
#          '목표': 46,
#          '방이': 5,
#          '주력': 25,
#          '게': 208,
#          '단편': 3,
#          '소설': 95,
#          '거': 171,
#          '신의': 14,
#          '선역': 3,
#          '네임드': 8,
#          '인지': 40,
#          '리지': 27,
#          '널': 35,
#          '지휘': 43,
#          '기술': 164,
#          '활용': 86,
#          '어': 21,
#          '레인지': 5,
#          '스킨': 52,
#          '람': 1,
#          '모델링': 14,
#          '차원': 43,
#          '귀환': 26,
#          '원군': 1,
#          '달리': 140,
#          '사망': 260,
#          '이펙트': 12,
#          '처리': 75,
#          '황금기': 4,
#          '고위': 21,
#          '아이어': 3,
#          '대기': 62,
#          '호출': 5,
#          '메뉴': 5,
#          '체력': 186,
#          '성경': 9,
#          '생체': 16,
#          '업': 61,
#          '방업': 33,
#          '막업': 26,
#          '방출': 20,
#          '공업': 45,
#          '중등': 5,
#          '법무관': 5,
#          '막강': 19,
#          '지역': 164,
#          '주지': 24,
#          '젤': 49,
#          '소진': 2,
#          '당': 91,
#          '석': 8,
#          '신검': 1,
#          '근접': 34,
#          '상지': 2,
#          '소용돌이': 8,
#          '자유': 41,
#          '파멸': 158,
#          '속삭임': 1,
#          '카라스': 2,
#          '계급': 11,
#          '초상화': 7,
#          '구성은': 2,
#          '정석': 8,
#          '질템': 2,
#          '위력': 55,
#          '머릿수': 5,
#          '살변': 3,
#          '링링': 3,
#          '바이오': 32,
#          '닉': 38,
#          '물량': 6,
#          '굳이': 33,
#          '다수': 46,
#          '상대': 337,
#          '위주': 38,
#          '만만': 2,
#          '찮': 1,
#          '일단': 82,
#          '쓸모': 8,
#          '메카': 19,
#          '토스': 108,
#          '상대로': 62,
#          '효율': 51,
#          '유형': 6,
#          '보고': 148,
#          '멀티': 19,
#          '자주': 106,
#          '경향': 25,
#          '초반': 152,
#          '평타': 59,
#          '깡통': 8,
#          '전락': 4,
#          '경우': 624,
#          '발생': 80,
#          '탓': 45,
#          '만약': 34,
#          '방향': 36,
#          '핵심': 32,
#          '딜러': 71,
#          '정작': 44,
#          '산화': 6,
#          '대물': 1,
#          '량전': 1,
#          '전담': 8,
#          '바람': 103,
#          '왜': 49,
#          '만만찮': 1,
#          '약점': 25,
#          '의견': 75,
#          '사실': 389,
#          '스토리': 84,
#          '거신': 3,
#          '접점': 9,
#          '남발': 6,
#          '도중': 62,
#          '십상': 4,
#          '범용': 8,
#          '대항': 13,
#          '차라리': 12,
#          '낫': 8,
#          '중이': 47,
#          '무엇': 46,
#          '화': 324,
#          '보안': 31,
#          '불사조': 3,
#          '중력자': 5,
#          '심지어': 115,
#          '중지': 17,
#          '획득': 25,
#          '존재': 154,
#          '여담': 89,
#          '신경': 47,
#          '인': 71,
#          '기조': 3,
#          '정밀': 14,
#          '타격': 50,
#          '기입': 2,
#          '니': 9,
#          '단일': 25,
#          '포격': 9,
#          '정렬': 3,
#          '공력': 1,
#          '조종사': 2,
#          '기존': 61,
#          '여성': 70,
#          '가면': 45,
#          '부분': 170,
#          '사도': 19,
#          '대체': 27,
#          '본인': 161,
#          '포함': 102,
#          '보라': 15,
#          '전쟁': 94,
#          '의회': 18,
#          '사양': 11,
#          '다단계': 1,
#          '기지': 31,
#          '돌파': 29,
#          '비교': 92,
#          '발휘': 26,
#          '이면': 32,
#          '포격기답': 1,
#          '최고': 94,
#          '마찬가지': 96,
#          '확장': 34,
#          '바위': 33,
#          '부수': 17,
#          '어그': 23,
#          '주기도': 9,
#          '몇': 54,
#          '분만': 3,
#          '셈': 66,
#          '다른': 460,
#          '따위': 15,
#          '압도': 57,
#          '난': 81,
#          '오브젝트': 14,
#          '후반': 56,
#          '활약': 69,
#          '형식': 21,
#          '점': 342,
#          '그대': 9,
#          '보통': 72,
#          '순식간': 26,
#          '게다가': 98,
#          '공허포격기': 1,
#          '선': 76,
#          '딜도': 5,
#          '킹': 45,
#          '포격기들': 2,
#          '꼴': 17,
#          '연출': 32,
#          '백업': 19,
#          '길': 41,
#          '거대': 17,
#          '격류': 2,
#          '정신': 91,
#          '자폭': 27,
#          '격파': 22,
#          '유동': 7,
#          '변화': 36,
#          '진홍': 2,
#          '자체': 232,
#          '캠페인': 9,
#          '기반': 31,
#          '또': 84,
#          '대신': 129,
#          '무력': 18,
#          '전작': 20,
#          '이번': 52,
#          '작': 33,
#          '적용': 75,
#          '소모': 40,
#          '양도': 6,
#          '딜링': 25,
#          '약간': 75,
#          '통한': 24,
#          '교란': 6,
#          '특': 9,
#          '거의': 197,
#          '판정': 47,
#          '몸빵': 2,
#          '고급': 24,
#          '적진': 21,
#          '지배': 33,
#          '이상': 216,
#          '저글링': 6,
#          '쪽': 166,
#          '수도': 138,
#          '면': 82,
#          '철거': 14,
#          '뿐더러': 8,
#          '목적': 50,
#          '적극': 53,
#          '플레이': 89,
#          '권장': 9,
#          '죽음': 89,
#          '밤': 37,
#          '변형': 15,
#          '명의': 86,
#          '공식': 123,
#          '석상': 4,
#          '명법': 1,
#          '전혀': 92,
#          '폐기': 3,
#          '가능성': 96,
#          '태사': 1,
#          '간': 53,
#          '트리': 44,
#          '더미': 5,
#          '데이터': 10,
#          '에이': 30,
#          '더스': 1,
#          '서세스': 1,
#          '엉터리': 2,
#          '렉션': 1,
#          '보조': 25,
#          '다만': 189,
#          '하자': 42,
#          '터': 130,
#          '택일': 3,
#          '수정과': 4,
#          '기준': 166,
#          '대개': 11,
#          '발사': 60,
#          '주문': 89,
#          '지도': 19,
#          '끝': 87,
#          '일직선': 3,
#          '집중': 33,
#          '방법': 79,
#          '차이점': 15,
#          '원본': 7,
#          '각개': 59,
#          '용도': 21,
#          '운용': 27,
#          '법': 59,
#          '본디': 9,
#          '장땡': 1,
#          '반드시': 35,
#          '실전': 16,
#          '제': 122,
#          '더라도': 3,
#          '문제점': 29,
#          '열': 27,
#          '경쟁': 29,
#          '포기': 62,
#          '메리트': 11,
#          '불가': 22,
#          '페널티': 4,
#          '감수': 8,
#          '매번': 6,
#          '계산': 18,
#          '감속': 3,
#          '딜': 82,
#          '이기': 135,
#          '보완': 10,
#          '구조': 63,
#          '탐지기': 8,
#          '은폐': 24,
#          '잠복': 3,
#          '탐지': 9,
#          '충격': 42,
#          '이전': 111,
#          '클릭': 15,
#          '제공': 75,
#          '타워': 30,
#          '케이': 19,
#          '다린': 2,
#          '생김새': 8,
#          '환영': 50,
#          '수동': 36,
#          '제거': 21,
#          '본체': 32,
#          '맷집': 6,
#          '먼지': 5,
#          '수준': 147,
#          '링': 27,
#          '원용': 2,
#          '스택': 13,
#          '시한': 2,
#          '부가': 15,
#          '쿨타임': 48,
#          '둘': 110,
#          '매우': 204,
#          '뼈': 12,
#          '조심': 6,
#          '딜링하': 1,
#          '그림': 44,
#          '완성': 41,
#          '금방': 6,
#          '지상군': 3,
#          '위협': 28,
#          '오기': 9,
#          '포트': 32,
#          '낫다': 12,
#          '거기': 79,
#          '다가': 44,
#          '맷': 4,
#          '포탑': 65,
#          '겨우': 19,
#          '잡기': 12,
#          '투사': 7,
#          '교': 10,
#          '전시': 18,
#          '최소': 32,
#          '의의': 8,
#          '물량유닛': 1,
#          '밀고': 7,
#          '수만': 6,
#          '정리': 40,
#          '구석': 3,
#          '아두': 1,
#          '현장': 29,
#          '빈집': 1,
#          '털': 6,
#          '방어선': 10,
#          '에필로그': 8,
#          '타락': 4,
#          '이속': 6,
#          '디버프': 6,
#          '부여': 27,
#          '장판': 8,
#          '포효': 2,
#          '봉인': 7,
#          '약화': 11,
#          '시킴': 6,
#          '실질': 22,
#          '주기': 21,
#          '테서렉트': 5,
#          '매': 12,
#          '교전': 29,
#          '취향': 12,
#          '분쇄': 4,
#          '맵': 41,
#          '클리어': 20,
#          '코랄': 3,
#          '균열': 16,
#          '승천': 14,
#          '사슬': 9,
#          '공략': 23,
#          '공짜': 5,
#          '한국': 353,
#          '서버': 6,
#          '스타일': 28,
#          '순간': 83,
#          '투자': 50,
#          '따라서': 50,
#          '분': 155,
#          '패': 139,
#          '시브': 40,
#          '식': 81,
#          '결정': 120,
#          '시점': 90,
#          '실수': 22,
#          '로라': 5,
#          '잘못': 28,
#          '빌드': 29,
#          '굴리': 3,
#          '매트릭스': 3,
#          '심플': 5,
#          '체감': 18,
#          '실로': 17,
#          '이득': 29,
#          '보': 51,
#          '대미지': 38,
#          '한덕': 2,
#          '미네랄': 10,
#          '구역': 25,
#          '뜻': 90,
#          '초으': 1,
#          '수량': 5,
#          '배': 137,
#          '렉트': 2,
#          '필수': 39,
#          '두번째': 20,
#          '습득': 7,
#          '확보': 41,
#          '최': 53,
#          '우선': 27,
#          '용': 115,
#          '오역': 8,
#          '일상': 9,
#          ...})

# %%
Image("6.jpg")
#https://wikidocs.net/46758
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-529c6c5b9dba> in <module>
# ----> 1 Image("6.jpg")
#       2 #https://wikidocs.net/46758
#
# NameError: name 'Image' is not defined

# %% [markdown]
# -----

# %% [markdown]
# ### [키워드 가다듬기]

# %% [markdown]
# ##### 한글자 키워드 제거

# %%
# 한글자 키워드를 제거합니다.
remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
print(remove_char_counter)
# Out:
# Counter({
'차량': 108, '유비': 108, '전부': 107, '라인': 107, '진행': 107, '우리': 107, '지속': 106, '거나': 106, '자주': 106, '개요': 105, '전송': 105, '이자': 105, '원래': 105, '팬덤': 105, '증가': 104, '발동': 104, '여러': 104, '운명': 104, '국적': 104, '특성': 103, '장갑': 103, '바람': 103, '원작': 103, '인수': 103, '요구': 102, '포함': 102, '합병': 102, '교육': 101, '병력': 101, '역사': 101, '라면': 100, '행동': 100, '사회': 100, '아버지': 100, '도끼': 100, '기도': 99, '회복': 99, '그대로': 99, '국가': 99, '크라켄': 99, '이미지': 98, '게다가': 98, '번호': 98, '신격호': 98, '작품': 97, '시장': 97, '설정': 96, '마찬가지': 96, '가능성': 96, '초기': 96, '라티': 96, '소설': 95, '소리': 94, '대사': 94, '군단': 94, '부대': 94, '만큼': 94, '전쟁': 94, '최고': 94, '제국': 94, '부차': 94, '아이': 93, '전적': 93, '출연': 93, '러블리즈': 93, '비교': 92, '전혀': 92, '주장': 92, '조사': 92, '정부': 92, '공개': 92, '대한민국': 92, '돌궐': 92, '정신': 91, '자리': 91, '패치': 91, '학살': 91, '다년': 91, '국내': 91, '필요': 90, '시점': 90, '중국': 90, '화물': 90, '길드': 90, '여담': 89, '플레이': 89, '죽음': 89, '주문': 89, '주로': 89, '입장': 89, '무시': 89, '규격': 89, '에리': 89, '센터': 89, '성격': 88, '동시': 88, '사항': 88, '영상': 88, '방송': 88, '사명': 88, '발바': 88, '신동빈': 88, '주변': 87, '설립': 87, '성능': 86, '활용': 86, '명의': 86, '영화': 86, '승객': 86, '비판': 85, '스토리': 84, '확인': 84, '남자': 84, '생산': 83, '폭발': 83, '파괴': 83, '역할': 83, '순간': 83, '가가': 83, '위키': 83, '재사용': 82, '일단': 82, '비중': 82, '냉매': 82, '신성현': 82, '방식': 81, '대표': 81, '묘사': 81, '쿠델리아': 81, '사거리': 80, '발생': 80, '덕분': 80, '난이도': 80, '삼성': 80, '항해사': 80, '아이템': 80, '지상': 79, '공중': 79, '방법': 79, '거기': 79, '그것': 79, '여자': 79, '가족': 79, '아트': 79, '도움': 78, '미국': 78, '아스': 78, '소속': 78, '테서랙트': 77, '범위': 77, '변경': 77, '제작': 77, '부상': 77, '애니메이션': 77, '과정': 76, ' ...

# %% [markdown]
# -----

# %% [markdown]
# ### [개념짚기] 컬렉션 축약
#
# : 컬렉션 (리스트, 집합, 사전) 생성후 값을 추가하는 것이 아니라
#
# 컬렉션 생성시 컬렉션내에서 for 문을 사용해 다른 컬렉션의 값들을 한줄로 간략하게 추가합니다.
#
# #### - 리스트 축약(내포)
# #### - 집합 축약(내포)
# #### - 사전 축약(내포)

# %%
from IPython.display import Image

Image("11.jpg")
#https://wikidocs.net/26565

# %%
from IPython.display import Image

Image("12.jpg")
#https://wikidocs.net/26565

# %%
from IPython.display import Image

Image("12.jpg")
#https://wikidocs.net/26565

# %% [markdown]
# ##### 불용어 제거

# %%
from IPython.display import Image

Image("13.jpg")
#https://wikidocs.net/13

# %%
# 한국어 약식 불용어사전 예시 파일입니다. 출처 - (https://www.ranks.nl/stopwords/korean)
korean_stopwords_path = "../data/korean_stopwords.txt"

# 텍스트 파일을 오픈합니다.
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]
print(stopwords[:10])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라']

# %%
# 나무위키 페이지에 맞는 불용어를 추가합니다.
namu_wiki_stopwords = ['상위', '문서', '내용', '누설', '아래', '해당', '설명', '표기', '추가', '모든', '사용', '매우', '가장',
                       '줄거리', '요소', '상황', '편집', '틀', '경우', '때문', '모습', '정도', '이후', '사실', '생각', '인물', 
                       '이름', '년월']
for stopword in namu_wiki_stopwords:
    stopwords.append(stopword)

# %%
from IPython.display import Image

Image("9.jpg")

# %%
# 키워드 데이터에서 불용어를 제거합니다.
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})
print(remove_char_counter)
# Out:
# Counter({'롯데': 841, '파트': 809, '공격': 628, '능력': 600, '사람': 519, '경차': 410, '유닛': 407, '미카즈키': 399, '다리우스': 398, '등장': 377, '위해': 369, '일본': 355, '한국': 353, '상대': 337, '대한': 326, '문제': 315, '유물': 309, '그룹': 290, '캐릭터': 289, '가장': 285, '당시': 264, '괴물': 263, '사망': 260, '스킬': 250, '시즌': 249, '제라툴': 248, '전투': 248, '가지': 248, '기본': 247, '시작': 245, '피해': 244, '쿼터': 244, '자체': 232, '상태': 230, '대학': 230, '방어': 222, '속도': 221, '실제': 217, '이유': 216, '운영': 215, '사건': 214, '현재': 213, '관련': 212, '바다': 209, '평가': 205, '건담': 204, '공허': 201, '주인공': 200, '전사': 198, '시리즈': 194, '랩처': 194, '보호': 191, '게임': 186, '체력': 186, '경기': 186, '다시': 185, '이용': 184, '서원대학교': 184, '챔피언': 183, '탈출': 183, '젤나가': 175, '편이': 174, '효과': 174, '마법': 174, '선수': 174, '부분': 170, '대해': 169, '기준': 166, '기술': 164, '지역': 164, '처음': 164, '회사': 163, '소환': 161, '본인': 161, '통해': 160, '역시': 160, '대부분': 159, '카드': 159, '파멸': 158, '라이언': 157, '활동': 156, '사령관': 155, '선원': 155, '존재': 154, '갑판': 154, '레이': 152, '초반': 152, '치어리더': 152, '지금': 151, '기록': 150, '건물': 150, '보고': 148, '직접': 147, '수준': 147, '학생': 147, '멤버': 147, '계속': 146, '그냥': 145, '성우': 145, '강화': 142, '이동': 141, '달리': 140, '베를린': 140, '지원': 139, '일부': 139, '녹서스': 139, '기사': 138, '수도': 138, '기업': 138, '회장': 138, '조각': 137, '대상': 136, '과거': 136, '이기': 135, '언급': 135, '포로': 135, '시체': 135, '레벨': 134, '비용': 132, '소련군': 132, '위치': 131, '발견': 130, '일반': 129, '선택': 129, '대신': 129, '정보': 129, '장면': 129, '참고': 128, '사이': 128, '학교': 127, '감소': 125, '최종': 125, '살인': 125, '사업': 125, '결과': 124, '공식': 123, '관계': 123, '학과': 123, '인어': 122, '마지막': 121, '출혈': 121, '이완용': 121, '무기': 120, '제대로': 120, '결정': 120, '이야기': 120, '머리': 119, '화단': 119, '관리': 118, '로이킴': 117, '최대': 115, '중첩': 115, '점멸': 114, '크게': 114, '교수': 114, '주의': 113, '유지': 113, '가격': 113, '
# - 아래 코드 실행을 위해, anaconda prompt 혹은 Terminal에서 아래와 같은 패키지들을 설치해 줍니다.
#     - (env_name) `pip install pytagcloud pygame simplejson`
# - 그리고 아래와 같은 경로에 한글 폰트(예: NanumBarunGothic.ttf) 파일을 옮깁니다.
#     - Mac OS : /{anaconda_path}/envs/{env_name}/lib/python3.7/site-packages/pytagcloud/fonts
#     - Windosw OS : \{anaconda_path}\envs\{env_name}\Lib\site-packages\pytagcloud\fonts
#     - `폰트 다운로드 : http://hangeul.naver.com/webfont/NanumGothic/NanumGothic.ttf`
# - 파일을 옮긴 후, 파이썬 가상환경을 재실행 하여 주피터를 다시 실행해줍니다. 그래도 아래의 코드가 실행되지 않는 경우는 다음과 같은 작업을 수행합니다.
#     - 위의 경로에서 font.json 파일을 편집합니다.
#     - 아래와 같은 코드를 추가하고 font.json 파일을 저장합니다.
#     - {
#                 "name": "NanumGothic",
#                 "ttf": "NanumGothic.ttf",
#                 "web": "http://fonts.googleapis.com/css?family=Nanum+Gothic"
#         },

# %% [markdown]
# #https://thinkwarelab.wordpress.com/2016/08/30/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%ED%98%95%ED%83%9C%EC%86%8C-%EB%B6%84%EC%84%9D%EC%9C%BC%EB%A1%9C-%EC%9B%8C%EB%93%9C%ED%81%B4%EB%9D%BC%EC%9A%B0%EB%93%9C-%EA%B7%B8%EB%A6%AC%EA%B8%B0/

# %%
import random
import pytagcloud
import webbrowser

# 가장 출현 빈도수가 높은 40개의 단어를 선정합니다.
ranked_tags = remove_char_counter.most_common(40)

# pytagcloud로 출력할 40개의 단어를 입력합니다. 단어 출력의 최대 크기는 80으로 제한합니다.
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)

# pytagcloud 이미지를 생성합니다. 폰트는 나눔 고딕을 사용합니다.
pytagcloud.create_tag_image(taglist, 'wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 생성한 이미지를 주피터 노트북상에서 출력합니다.
from IPython.display import Image
Image(filename='wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ### [나무위키 키워드 시각화]

# %% [markdown]
# ##### 제목 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(title_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'title_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='title_wordcloud.jpg')

# %% [markdown]
# -----

# %% [markdown]
# ##### 카테고리 키워드

# %%
nouns_tagger = Okt()
nouns = nouns_tagger.nouns(category_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x : count[x] for x in count if len(x) > 1})
remove_char_counter = Counter({x : remove_char_counter[x] for x in count if x not in stopwords})

ranked_tags = remove_char_counter.most_common(40)
taglist = pytagcloud.make_tags(ranked_tags, maxsize=80)
pytagcloud.create_tag_image(taglist, 'category_wordcloud.jpg', size=(900, 600), fontname='NanumGothic', rectangular=False)

Image(filename='category_wordcloud.jpg')

# %% [markdown]
# # Forecasting Models : SMA, WMA, SES, ARIMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
# %matplotlib inline

# %%
airline = pd.read_csv('./data/airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %% [markdown]
# ## Simple Moving Average

# %% [markdown]
# Moving Average 구하는 방법에 대해서는 앞서 rolling mean 을 통해 알아본 바 있습니다.

# %%
airline['6M SMA'] = airline['Thousands of Passengers'].rolling(window=6).mean()
airline['12M SMA'] = airline['Thousands of Passengers'].rolling(window=12).mean()

# %%
airline.head(15)
# Out:
#             Thousands of Passengers      6M SMA     12M SMA
# Month
# 1949-01-01                      112         NaN         NaN
# 1949-02-01                      118         NaN         NaN
# 1949-03-01                      132         NaN         NaN
# 1949-04-01                      129         NaN         NaN
# 1949-05-01                      121         NaN         NaN
# 1949-06-01                      135  124.500000         NaN
# 1949-07-01                      148  130.500000         NaN
# 1949-08-01                      148  135.500000         NaN
# 1949-09-01                      136  136.166667         NaN
# 1949-10-01                      119  134.500000         NaN
# 1949-11-01                      104  131.666667         NaN
# 1949-12-01                      118  128.833333  126.666667
# 1950-01-01                      115  123.333333  126.916667
# 1950-02-01                      126  119.666667  127.583333
# 1950-03-01                      141  120.500000  128.333333

# %%
np.sqrt(mean_squared_error(airline['Thousands of Passengers'][12:], airline['12M SMA'][12:]))
# Out:
# 48.18484843919034

# %%
np.sqrt(mean_squared_error(airline['Thousands of Passengers'][6:], airline['6M SMA'][6:]))
# Out:
# 45.89221733492798

# %%
airline.plot(figsize=(12,8))
plt.show()

# %% [markdown]
# ## Weighted Moving Averagem

# %%
airline['WMA12'] = airline['Thousands of Passengers'].ewm(span=12).mean()
airline['WMA6'] = airline['Thousands of Passengers'].ewm(span=6).mean()

# %%
airline.head(15)
# Out:
#             Thousands of Passengers      6M SMA     12M SMA       WMA12  \
# Month
# 1949-01-01                      112         NaN         NaN  112.000000
# 1949-02-01                      118         NaN         NaN  115.250000
# 1949-03-01                      132         NaN         NaN  121.787529
# 1949-04-01                      129         NaN         NaN  124.064224
# 1949-05-01                      121         NaN         NaN  123.231685
# 1949-06-01                      135  124.500000         NaN  126.092005
# 1949-07-01                      148  130.500000         NaN  130.980697
# 1949-08-01                      148  135.500000         NaN  134.532364
# 1949-09-01                      136  136.166667         NaN  134.822714
# 1949-10-01                      119  134.500000         NaN  131.824316
# 1949-11-01                      104  131.666667         NaN  126.733137
# 1949-12-01                      118  128.833333  126.666667  125.180414
# 1950-01-01                      115  123.333333  126.916667  123.412707
# 1950-02-01                      126  119.666667  127.583333  123.853241
# 1950-03-01                      141  120.500000  128.333333  126.725616
#
#                   WMA6
# Month
# 1949-01-01  112.000000
# 1949-02-01  115.500000
# 1949-03-01  122.917431
# 1949-04-01  125.266892
# 1949-05-01  123.769332
# 1949-06-01  127.469517
# 1949-07-01  133.950151
# 1949-08-01  138.256171
# 1949-09-01  137.578764
# 1949-10-01  132.080461
# 1949-11-01  123.854336
# 1949-12-01  122.151635
# 1950-01-01  120.082239
# 1950-02-01  121.788382
# 1950-03-01  127.312928

# %%
np.sqrt(mean_squared_error(airline['Thousands of Passengers'], airline['WMA12']))
# Out:
# 41.312675718459396

# %%
np.sqrt(mean_squared_error(airline['Thousands of Passengers'], airline['WMA6']))
# Out:
# 32.825310766356665

# %%
airline[['Thousands of Passengers', 'WMA6','WMA12']].plot(figsize=(12,8))
plt.show()

# %% [markdown]
# ## Simple Exponential Smoothing

# %%
from statsmodels.tsa.api import SimpleExpSmoothing

# %%
train = airline[:'1959']
test = airline['1960':]

# %%
train['Thousands of Passengers'].plot(figsize=(12,8))
test['Thousands of Passengers'].plot()
plt.show()

# %%
ses_model = SimpleExpSmoothing(np.asarray(train['Thousands of Passengers']))

# %%
ses_result = ses_model.fit()
# Out:
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub

# %%
y_hat = test.copy()

# %%
y_hat['SES'] = ses_result.forecast(len(test))

# %%
plt.figure(figsize=(12,8))
plt.plot(train['Thousands of Passengers'], label='Train')
plt.plot(test['Thousands of Passengers'], label='Test')
plt.plot(y_hat['SES'], label='Simple Exp Smoothing')
plt.legend()
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Thousands of Passengers'], y_hat['SES']))

# %%
rmse
# Out:
# 102.97653454387881

# %% [markdown]
# ## Holt's Method

# %%
from statsmodels.tsa.api import Holt

# %%
holt_model = Holt(np.asarray(train['Thousands of Passengers']))

# %%
holt_result = holt_model.fit()

# %%
y_hat['HOLT'] = holt_result.forecast(len(test))

# %%
plt.figure(figsize=(12,8))
plt.plot(train['Thousands of Passengers'], label='Train')
plt.plot(test['Thousands of Passengers'], label='Test')
plt.plot(y_hat['HOLT'], label='Holts Exp Smoothing')
plt.legend()

# %%
rmse = np.sqrt(mean_squared_error(test['Thousands of Passengers'], y_hat['HOLT']))

# %%
rmse
# Out:
# 92.6663528028185

# %% [markdown]
# ## Holt-Winters Method

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# %%
winter_model = ExponentialSmoothing(
    np.asarray(train['Thousands of Passengers']),
    seasonal_periods=12, trend='add', seasonal='add'
)

# %%
winter_result = winter_model.fit()
# Out:
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\holtwinters.py:725: RuntimeWarning: invalid value encountered in less_equal
#   loc = initial_p <= lb
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\holtwinters.py:731: RuntimeWarning: invalid value encountered in greater_equal
#   loc = initial_p >= ub
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
y_hat['WINTER'] = winter_result.forecast(len(test))

# %%
plt.figure(figsize=(12,8))
plt.plot(train['Thousands of Passengers'], label='Train')
plt.plot(test['Thousands of Passengers'], label='Test')
plt.plot(y_hat['WINTER'], label='Holt-Winters Exp Smoothing')
plt.legend()

# %%
rmse = np.sqrt(mean_squared_error(test['Thousands of Passengers'],y_hat['WINTER']))

# %%
rmse
# Out:
# 15.570830560604868

# %% [markdown]
# ## ARIMA

# %%
import statsmodels.api as sm

# %%
# ARIMA(p,d,q)(P,D,Q)m

arima = sm.tsa.statespace.SARIMAX(train['Thousands of Passengers'],
                                  order=(2,1,1),
                                  seasonal_order=(0,1,0,12),
                                  enforce_stationarity=False,
                                  enforce_invertibility=False)
# Out:
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\Wyatt\anaconda3\envs\wyatt37\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %%
arima_result = arima.fit()

# %%
y_hat['ARIMA'] = arima_result.predict(start='1960-01-01', end='1960-12-01', dynamic=True)

# %%
plt.figure(figsize=(12,8))
plt.plot(train['Thousands of Passengers'], label='Train')
plt.plot(test['Thousands of Passengers'], label='Test')
plt.plot(y_hat['ARIMA'], label='Seasonal ARIMA')
plt.legend()

# %%
rmse = np.sqrt(mean_squared_error(test['Thousands of Passengers'],y_hat['ARIMA']))

# %%
rmse
# Out:
# 22.65217468234728
